# %% [markdown]
# # Upgrade an dari Template Klasifikasi2 Alias simplifikasi ( to the point)

# %%
import numpy as np
import pandas as pd
import os
import sys
# sys.path.append('c:\python39\lib\site-packages')
import cv2
import pathlib

for dirname, _, filenames in os.walk('../Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
from sklearn import model_selection, svm, preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix
from matplotlib.pyplot import figure
from keras.utils import to_categorical
import seaborn as sns

# %%
data_dir = "Dataset"  # Datasets path
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# WindowsPath('Dataset')

# %%
Bribil = list(data_dir.glob('Bribil/*'))
Picis = list(data_dir.glob('Picis/*'))
Sen = list(data_dir.glob('Sen/*'))

# %%
train_img = {
    'Bribil': Bribil,
    'Picis': Picis,
    'Sen': Sen
}

train_label = {
    'Bribil': 0,
    'Picis': 1,
    'Sen': 2
}

# %%
df_images = {
    'Bribil': Bribil,
    'Picis': Picis,
    'Sen': Sen
}
df_labels = {
    'Bribil': 0,
    'Picis': 1,
    'Sen': 2
}

# %%
train_img
# Out:
# {'Bribil': [WindowsPath('Dataset/Bribil/bribil (1).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (10).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (100).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (11).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (12).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (13).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (14).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (15).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (16).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (17).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (18).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (19).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (2).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (20).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (21).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (22).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (23).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (24).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (25).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (26).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (27).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (28).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (29).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (3).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (30).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (31).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (32).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (33).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (34).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (35).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (36).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (37).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (38).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (39).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (4).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (40).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (41).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (42).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (43).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (44).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (45).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (46).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (47).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (48).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (49).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (5).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (50).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (51).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (52).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (53).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (54).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (55).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (56).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (57).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (58).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (59).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (6).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (60).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (61).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (62).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (63).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (64).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (65).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (66).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (67).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (68).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (69).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (7).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (70).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (71).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (72).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (73).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (74).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (75).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (76).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (77).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (78).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (79).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (8).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (80).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (81).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (82).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (83).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (84).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (85).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (86).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (87).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (88).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (89).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (9).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (90).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (91).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (92).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (93).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (94).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (95).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (96).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (97).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (98).jpg'),
#   WindowsPath('Dataset/Bribil/bribil (99).jpg')],
#  'Picis': [WindowsPath('Dataset/Picis/picis (1).jpg'),
#   WindowsPath('Dataset/Picis/picis (10).jpg'),
#   WindowsPath('Dataset/Picis/picis (100).jpg'),
#   WindowsPath('Dataset/Picis/picis (11).jpg'),
#   WindowsPath('Dataset/Picis/picis (12).jpg'),
#   WindowsPath('Dataset/Picis/picis (13).jpg'),
#   WindowsPath('Dataset/Picis/picis (14).jpg'),
#   WindowsPath('Dataset/Picis/picis (15).jpg'),
#   WindowsPath('Dataset/Picis/picis (16).jpg'),
#   WindowsPath('Dataset/Picis/picis (17).jpg'),
#   WindowsPath('Dataset/Picis/picis (18).jpg'),
#   WindowsPath('Dataset/Picis/picis (19).jpg'),
#   WindowsPath('Dataset/Picis/picis (2).jpg'),
#   WindowsPath('Dataset/Picis/picis (20).jpg'),
#   WindowsPath('Dataset/Picis/picis (21).jpg'),
#   WindowsPath('Dataset/Picis/picis (22).jpg'),
#   WindowsPath('Dataset/Picis/picis (23).jpg'),
#   WindowsPath('Dataset/Picis/picis (24).jpg'),
#   WindowsPath('Dataset/Picis/picis (25).jpg'),
#   WindowsPath('Dataset/Picis/picis (26).jpg'),
#   WindowsPath('Dataset/Picis/picis (27).jpg'),
#   WindowsPath('Dataset/Picis/picis (28).jpg'),
#   WindowsPath('Dataset/Picis/picis (29).jpg'),
#   WindowsPath('Dataset/Picis/picis (3).jpg'),
#   WindowsPath('Dataset/Picis/picis (30).jpg'),
#   WindowsPath('Dataset/Picis/picis (31).jpg'),
#   WindowsPath('Dataset/Picis/picis (32).jpg'),
#   WindowsPath('Dataset/Picis/picis (33).jpg'),
#   WindowsPath('Dataset/Picis/picis (34).jpg'),
#   WindowsPath('Dataset/Picis/picis (35).jpg'),
#   WindowsPath('Dataset/Picis/picis (36).jpg'),
#   WindowsPath('Dataset/Picis/picis (37).jpg'),
#   WindowsPath('Dataset/Picis/picis (38).jpg'),
#   WindowsPath('Dataset/Picis/picis (39).jpg'),
#   WindowsPath('Dataset/Picis/picis (4).jpg'),
#   WindowsPath('Dataset/Picis/picis (40).jpg'),
#   WindowsPath('Dataset/Picis/picis (41).jpg'),
#   WindowsPath('Dataset/Picis/picis (42).jpg'),
#   WindowsPath('Dataset/Picis/picis (43).jpg'),
#   WindowsPath('Dataset/Picis/picis (44).jpg'),
#   WindowsPath('Dataset/Picis/picis (45).jpg'),
#   WindowsPath('Dataset/Picis/picis (46).jpg'),
#   WindowsPath('Dataset/Picis/picis (47).jpg'),
#   WindowsPath('Dataset/Picis/picis (48).jpg'),
#   WindowsPath('Dataset/Picis/picis (49).jpg'),
#   WindowsPath('Dataset/Picis/picis (5).jpg'),
#   WindowsPath('Dataset/Picis/picis (50).jpg'),
#   WindowsPath('Dataset/Picis/picis (51).jpg'),
#   WindowsPath('Dataset/Picis/picis (52).jpg'),
#   WindowsPath('Dataset/Picis/picis (53).jpg'),
#   WindowsPath('Dataset/Picis/picis (54).jpg'),
#   WindowsPath('Dataset/Picis/picis (55).jpg'),
#   WindowsPath('Dataset/Picis/picis (56).jpg'),
#   WindowsPath('Dataset/Picis/picis (57).jpg'),
#   WindowsPath('Dataset/Picis/picis (58).jpg'),
#   WindowsPath('Dataset/Picis/picis (59).jpg'),
#   WindowsPath('Dataset/Picis/picis (6).jpg'),
#   WindowsPath('Dataset/Picis/picis (60).jpg'),
#   WindowsPath('Dataset/Picis/picis (61).jpg'),
#   WindowsPath('Dataset/Picis/picis (62).jpg'),
#   WindowsPath('Dataset/Picis/picis (63).jpg'),
#   WindowsPath('Dataset/Picis/picis (64).jpg'),
#   WindowsPath('Dataset/Picis/picis (65).jpg'),
#   WindowsPath('Dataset/Picis/picis (66).jpg'),
#   WindowsPath('Dataset/Picis/picis (67).jpg'),
#   WindowsPath('Dataset/Picis/picis (68).jpg'),
#   WindowsPath('Dataset/Picis/picis (69).jpg'),
#   WindowsPath('Dataset/Picis/picis (7).jpg'),
#   WindowsPath('Dataset/Picis/picis (70).jpg'),
#   WindowsPath('Dataset/Picis/picis (71).jpg'),
#   WindowsPath('Dataset/Picis/picis (72).jpg'),
#   WindowsPath('Dataset/Picis/picis (73).jpg'),
#   WindowsPath('Dataset/Picis/picis (74).jpg'),
#   WindowsPath('Dataset/Picis/picis (75).jpg'),
#   WindowsPath('Dataset/Picis/picis (76).jpg'),
#   WindowsPath('Dataset/Picis/picis (77).jpg'),
#   WindowsPath('Dataset/Picis/picis (78).jpg'),
#   WindowsPath('Dataset/Picis/picis (79).jpg'),
#   WindowsPath('Dataset/Picis/picis (8).jpg'),
#   WindowsPath('Dataset/Picis/picis (80).jpg'),
#   WindowsPath('Dataset/Picis/picis (81).jpg'),
#   WindowsPath('Dataset/Picis/picis (82).jpg'),
#   WindowsPath('Dataset/Picis/picis (83).jpg'),
#   WindowsPath('Dataset/Picis/picis (84).jpg'),
#   WindowsPath('Dataset/Picis/picis (85).jpg'),
#   WindowsPath('Dataset/Picis/picis (86).jpg'),
#   WindowsPath('Dataset/Picis/picis (87).jpg'),
#   WindowsPath('Dataset/Picis/picis (88).jpg'),
#   WindowsPath('Dataset/Picis/picis (89).jpg'),
#   WindowsPath('Dataset/Picis/picis (9).jpg'),
#   WindowsPath('Dataset/Picis/picis (90).jpg'),
#   WindowsPath('Dataset/Picis/picis (91).jpg'),
#   WindowsPath('Dataset/Picis/picis (92).jpg'),
#   WindowsPath('Dataset/Picis/picis (93).jpg'),
#   WindowsPath('Dataset/Picis/picis (94).jpg'),
#   WindowsPath('Dataset/Picis/picis (95).jpg'),
#   WindowsPath('Dataset/Picis/picis (96).jpg'),
#   WindowsPath('Dataset/Picis/picis (97).jpg'),
#   WindowsPath('Dataset/Picis/picis (98).jpg'),
#   WindowsPath('Dataset/Picis/picis (99).jpg')],
#  'Sen': [WindowsPath('Dataset/Sen/sen (1).jpg'),
#   WindowsPath('Dataset/Sen/sen (10).jpg'),
#   WindowsPath('Dataset/Sen/sen (100).jpg'),
#   WindowsPath('Dataset/Sen/sen (11).jpg'),
#   WindowsPath('Dataset/Sen/sen (12).jpg'),
#   WindowsPath('Dataset/Sen/sen (13).jpg'),
#   WindowsPath('Dataset/Sen/sen (14).jpg'),
#   WindowsPath('Dataset/Sen/sen (15).jpg'),
#   WindowsPath('Dataset/Sen/sen (16).jpg'),
#   WindowsPath('Dataset/Sen/sen (17).jpg'),
#   WindowsPath('Dataset/Sen/sen (18).jpg'),
#   WindowsPath('Dataset/Sen/sen (19).jpg'),
#   WindowsPath('Dataset/Sen/sen (2).jpg'),
#   WindowsPath('Dataset/Sen/sen (20).jpg'),
#   WindowsPath('Dataset/Sen/sen (21).jpg'),
#   WindowsPath('Dataset/Sen/sen (22).jpg'),
#   WindowsPath('Dataset/Sen/sen (23).jpg'),
#   WindowsPath('Dataset/Sen/sen (24).jpg'),
#   WindowsPath('Dataset/Sen/sen (25).jpg'),
#   WindowsPath('Dataset/Sen/sen (26).jpg'),
#   WindowsPath('Dataset/Sen/sen (27).jpg'),
#   WindowsPath('Dataset/Sen/sen (28).jpg'),
#   WindowsPath('Dataset/Sen/sen (29).jpg'),
#   WindowsPath('Dataset/Sen/sen (3).jpg'),
#   WindowsPath('Dataset/Sen/sen (30).jpg'),
#   WindowsPath('Dataset/Sen/sen (31).jpg'),
#   WindowsPath('Dataset/Sen/sen (32).jpg'),
#   WindowsPath('Dataset/Sen/sen (33).jpg'),
#   WindowsPath('Dataset/Sen/sen (34).jpg'),
#   WindowsPath('Dataset/Sen/sen (35).jpg'),
#   WindowsPath('Dataset/Sen/sen (36).jpg'),
#   WindowsPath('Dataset/Sen/sen (37).jpg'),
#   WindowsPath('Dataset/Sen/sen (38).jpg'),
#   WindowsPath('Dataset/Sen/sen (39).jpg'),
#   WindowsPath('Dataset/Sen/sen (4).jpg'),
#   WindowsPath('Dataset/Sen/sen (40).jpg'),
#   WindowsPath('Dataset/Sen/sen (41).jpg'),
#   WindowsPath('Dataset/Sen/sen (42).jpg'),
#   WindowsPath('Dataset/Sen/sen (43).jpg'),
#   WindowsPath('Dataset/Sen/sen (44).jpg'),
#   WindowsPath('Dataset/Sen/sen (45).jpg'),
#   WindowsPath('Dataset/Sen/sen (46).jpg'),
#   WindowsPath('Dataset/Sen/sen (47).jpg'),
#   WindowsPath('Dataset/Sen/sen (48).jpg'),
#   WindowsPath('Dataset/Sen/sen (49).jpg'),
#   WindowsPath('Dataset/Sen/sen (5).jpg'),
#   WindowsPath('Dataset/Sen/sen (50).jpg'),
#   WindowsPath('Dataset/Sen/sen (51).jpg'),
#   WindowsPath('Dataset/Sen/sen (52).jpg'),
#   WindowsPath('Dataset/Sen/sen (53).jpg'),
#   WindowsPath('Dataset/Sen/sen (54).jpg'),
#   WindowsPath('Dataset/Sen/sen (55).jpg'),
#   WindowsPath('Dataset/Sen/sen (56).jpg'),
#   WindowsPath('Dataset/Sen/sen (57).jpg'),
#   WindowsPath('Dataset/Sen/sen (58).jpg'),
#   WindowsPath('Dataset/Sen/sen (59).jpg'),
#   WindowsPath('Dataset/Sen/sen (6).jpg'),
#   WindowsPath('Dataset/Sen/sen (60).jpg'),
#   WindowsPath('Dataset/Sen/sen (61).jpg'),
#   WindowsPath('Dataset/Sen/sen (62).jpg'),
#   WindowsPath('Dataset/Sen/sen (63).jpg'),
#   WindowsPath('Dataset/Sen/sen (64).jpg'),
#   WindowsPath('Dataset/Sen/sen (65).jpg'),
#   WindowsPath('Dataset/Sen/sen (66).jpg'),
#   WindowsPath('Dataset/Sen/sen (67).jpg'),
#   WindowsPath('Dataset/Sen/sen (68).jpg'),
#   WindowsPath('Dataset/Sen/sen (69).jpg'),
#   WindowsPath('Dataset/Sen/sen (7).jpg'),
#   WindowsPath('Dataset/Sen/sen (70).jpg'),
#   WindowsPath('Dataset/Sen/sen (71).jpg'),
#   WindowsPath('Dataset/Sen/sen (72).jpg'),
#   WindowsPath('Dataset/Sen/sen (73).jpg'),
#   WindowsPath('Dataset/Sen/sen (74).jpg'),
#   WindowsPath('Dataset/Sen/sen (75).jpg'),
#   WindowsPath('Dataset/Sen/sen (76).jpg'),
#   WindowsPath('Dataset/Sen/sen (77).jpg'),
#   WindowsPath('Dataset/Sen/sen (78).jpg'),
#   WindowsPath('Dataset/Sen/sen (79).jpg'),
#   WindowsPath('Dataset/Sen/sen (8).jpg'),
#   WindowsPath('Dataset/Sen/sen (80).jpg'),
#   WindowsPath('Dataset/Sen/sen (81).jpg'),
#   WindowsPath('Dataset/Sen/sen (82).jpg'),
#   WindowsPath('Dataset/Sen/sen (83).jpg'),
#   WindowsPath('Dataset/Sen/sen (84).jpg'),
#   WindowsPath('Dataset/Sen/sen (85).jpg'),
#   WindowsPath('Dataset/Sen/sen (86).jpg'),
#   WindowsPath('Dataset/Sen/sen (87).jpg'),
#   WindowsPath('Dataset/Sen/sen (88).jpg'),
#   WindowsPath('Dataset/Sen/sen (89).jpg'),
#   WindowsPath('Dataset/Sen/sen (9).jpg'),
#   WindowsPath('Dataset/Sen/sen (90).jpg'),
#   WindowsPath('Dataset/Sen/sen (91).jpg'),
#   WindowsPath('Dataset/Sen/sen (92).jpg'),
#   WindowsPath('Dataset/Sen/sen (93).jpg'),
#   WindowsPath('Dataset/Sen/sen (94).jpg'),
#   WindowsPath('Dataset/Sen/sen (95).jpg'),
#   WindowsPath('Dataset/Sen/sen (96).jpg'),
#   WindowsPath('Dataset/Sen/sen (97).jpg'),
#   WindowsPath('Dataset/Sen/sen (98).jpg'),
#   WindowsPath('Dataset/Sen/sen (99).jpg')]}

# %%
#train_x = train_img
#train_y = train_label

#test_x = test_img
#test_y = test_label

# %%
#len(train_y)

# %%
X, y = [], []
for label, images in df_images.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img, (256, 256))
        X.append(resized_img)
        y.append(df_labels[label])

# %%
print(X)
# Out:
# [array([[[138, 138, 144],
#         [141, 141, 147],
#         [140, 139, 145],
#         ...,
#         [146, 142, 151],
#         [145, 144, 153],
#         [140, 138, 147]],
#
#        [[140, 144, 149],
#         [139, 144, 149],
#         [138, 142, 147],
#         ...,
#         [143, 146, 151],
#         [139, 144, 149],
#         [138, 142, 147]],
#
#        [[132, 138, 143],
#         [137, 143, 148],
#         [136, 142, 147],
#         ...,
#         [142, 147, 152],
#         [140, 146, 151],
#         [137, 143, 148]],
#
#        ...,
#
#        [[174, 168, 174],
#         [158, 163, 168],
#         [101, 110, 103],
#         ...,
#         [ 35,  17,  27],
#         [109,  92,  99],
#         [175, 161, 168]],
#
#        [[173, 167, 174],
#         [170, 172, 180],
#         [145, 165, 167],
#         ...,
#         [143, 150, 151],
#         [ 31,  24,  26],
#         [ 56,  30,  43]],
#
#        [[182, 167, 175],
#         [178, 170, 181],
#         [157, 176, 172],
#         ...,
#         [172, 170, 177],
#         [162, 166, 172],
#         [124, 122, 128]]], dtype=uint8), array([[[111,  89, 137],
#         [106,  86, 133],
#         [110,  90, 135],
#         ...,
#         [233, 251, 252],
#         [230, 249, 249],
#         [233, 251, 250]],
#
#        [[110,  88, 136],
#         [108,  88, 135],
#         [109,  89, 135],
#         ...,
#         [234, 248, 253],
#         [237, 250, 253],
#         [241, 254, 254]],
#
#        [[109,  88, 135],
#         [109,  89, 136],
#         [110,  87, 137],
#         ...,
#         [216, 225, 234],
#         [201, 207, 218],
#         [201, 205, 216]],
#
#        ...,
#
#        [[229, 248, 251],
#         [231, 247, 254],
#         [220, 228, 241],
#         ...,
#         [ 74,  33,  78],
#         [ 75,  34,  77],
#         [ 75,  34,  76]],
#
#        [[233, 252, 254],
#         [234, 247, 255],
#         [206, 210, 227],
#         ...,
#         [ 75,  32,  79],
#         [ 76,  33,  78],
#         [ 76,  33,  76]],
#
#        [[226, 245, 252],
#         [237, 250, 254],
#         [209, 211, 227],
#         ...,
#         [ 75,  32,  79],
#         [ 78,  32,  78],
#         [ 78,  33,  76]]], dtype=uint8), array([[[200, 235, 162],
#         [ 89, 142,  53],
#         [ 58, 132,  20],
#         ...,
#         [181, 232, 159],
#         [ 77, 122,  59],
#         [168, 208, 145]],
#
#        [[117, 159,  75],
#         [189, 245, 149],
#         [ 59, 133,  20],
#         ...,
#         [142, 196, 112],
#         [ 55, 105,  29],
#         [171, 214, 142]],
#
#        [[ 83, 137,  33],
#         [160, 223, 115],
#         [143, 214, 101],
#         ...,
#         [ 84, 146,  41],
#         [ 59, 117,  17],
#         [176, 221, 136]],
#
#        ...,
#
#        [[188, 218, 143],
#         [ 61, 113,  14],
#         [ 76, 147,  23],
#         ...,
#         [143, 205, 107],
#         [134, 181, 105],
#         [176, 207, 149]],
#
#        [[120, 158,  75],
#         [ 80, 134,  32],
#         [ 61, 132,   8],
#         ...,
#         [ 91, 153,  53],
#         [191, 235, 166],
#         [197, 224, 178]],
#
#        [[ 68, 129,  19],
#         [ 72, 140,  27],
#         [ 63, 142,  16],
#         ...,
#         [ 69, 130,  26],
#         [158, 195, 135],
#         [236, 254, 224]]], dtype=uint8), array([[[  0,  76, 180],
#         [ 36, 148, 250],
#         [  0, 152, 251],
#         ...,
#         [ 12, 153, 255],
#         [  3, 144, 247],
#         [  0, 132, 235]],
#
#        [[  3,  94, 197],
#         [ 34, 151, 253],
#         [  0, 152, 252],
#         ...,
#         [  5, 148, 252],
#         [  2, 147, 250],
#         [  4, 144, 246]],
#
#        [[  3, 111, 215],
#         [ 26, 150, 252],
#         [  0, 150, 250],
#         ...,
#         [  1, 148, 252],
#         [  1, 151, 252],
#         [  4, 152, 254]],
#
#        ...,
#
#        [[  0, 109, 209],
#         [ 24, 154, 254],
#         [  0, 149, 250],
#         ...,
#         [  0, 150, 254],
#         [  1, 152, 254],
#         [  6, 144, 251]],
#
#        [[  0,  95, 192],
#         [ 33, 155, 253],
#         [  0, 147, 248],
#         ...,
#         [  0, 148, 254],
#         [  1, 152, 254],
#         [  2, 139, 244]],
#
#        [[  0,  87, 183],
#         [ 34, 152, 249],
#         [  0, 147, 249],
#         ...,
#         [  0, 147, 255],
#         [  0, 148, 253],
#         [  0, 130, 235]]], dtype=uint8), array([[[ 12, 129, 166],
#         [ 10, 126, 163],
#         [  9, 123, 160],
#         ...,
#         [ 23, 106, 159],
#         [ 24, 107, 163],
#         [ 30, 113, 169]],
#
#        [[ 14, 126, 164],
#         [ 13, 125, 162],
#         [ 14, 123, 160],
#         ...,
#         [ 25, 107, 160],
#         [ 25, 108, 163],
#         [ 29, 112, 167]],
#
#        [[ 16, 120, 159],
#         [ 17, 122, 158],
#         [ 21, 124, 160],
#         ...,
#         [ 30, 112, 162],
#         [ 30, 112, 164],
#         [ 32, 115, 167]],
#
#        ...,
#
#        [[ 60, 117, 129],
#         [ 94, 151, 163],
#         [121, 180, 191],
#         ...,
#         [ 88, 160, 166],
#         [102, 174, 180],
#         [111, 185, 188]],
#
#        [[ 65, 124, 134],
#         [ 93, 153, 162],
#         [116, 175, 185],
#         ...,
#         [ 86, 159, 163],
#         [102, 176, 179],
#         [114, 189, 191]],
#
#        [[ 62, 121, 130],
#         [ 80, 139, 148],
#         [ 92, 153, 162],
#         ...,
#         [ 85, 159, 162],
#         [ 96, 171, 173],
#         [105, 180, 182]]], dtype=uint8), array([[[228, 224, 229],
#         [229, 225, 230],
#         [153, 150, 154],
#         ...,
#         [132, 129, 131],
#         [143, 140, 142],
#         [247, 244, 246]],
#
#        [[233, 229, 234],
#         [150, 146, 151],
#         [ 93,  89,  94],
#         ...,
#         [135, 133, 135],
#         [ 84,  81,  83],
#         [178, 175, 177]],
#
#        [[113, 109, 114],
#         [ 98,  94,  99],
#         [158, 154, 159],
#         ...,
#         [189, 186, 188],
#         [128, 125, 128],
#         [ 60,  57,  59]],
#
#        ...,
#
#        [[237, 233, 238],
#         [163, 159, 164],
#         [151, 147, 152],
#         ...,
#         [234, 233, 237],
#         [239, 238, 242],
#         [252, 251, 254]],
#
#        [[239, 234, 239],
#         [217, 214, 219],
#         [145, 141, 146],
#         ...,
#         [237, 236, 240],
#         [237, 236, 240],
#         [248, 247, 251]],
#
#        [[243, 239, 244],
#         [229, 225, 230],
#         [161, 157, 162],
#         ...,
#         [234, 233, 237],
#         [228, 227, 231],
#         [235, 234, 238]]], dtype=uint8), array([[[195, 214, 195],
#         [200, 217, 205],
#         [202, 215, 217],
#         ...,
#         [180, 190, 200],
#         [181, 190, 199],
#         [181, 190, 199]],
#
#        [[188, 205, 191],
#         [210, 226, 218],
#         [211, 223, 229],
#         ...,
#         [183, 191, 204],
#         [183, 192, 203],
#         [183, 192, 203]],
#
#        [[185, 200, 193],
#         [218, 232, 230],
#         [211, 221, 233],
#         ...,
#         [182, 190, 206],
#         [183, 190, 205],
#         [183, 190, 205]],
#
#        ...,
#
#        [[176, 180, 198],
#         [187, 191, 211],
#         [190, 195, 218],
#         ...,
#         [199, 207, 219],
#         [199, 207, 219],
#         [200, 208, 220]],
#
#        [[168, 171, 188],
#         [179, 184, 201],
#         [186, 192, 213],
#         ...,
#         [199, 208, 216],
#         [199, 208, 215],
#         [200, 209, 216]],
#
#        [[154, 157, 172],
#         [165, 170, 185],
#         [176, 182, 202],
#         ...,
#         [202, 211, 217],
#         [203, 212, 216],
#         [204, 213, 217]]], dtype=uint8), array([[[198, 199, 189],
#         [198, 199, 189],
#         [199, 199, 190],
#         ...,
#         [202, 197, 187],
#         [202, 195, 185],
#         [200, 194, 183]],
#
#        [[200, 201, 190],
#         [200, 201, 191],
#         [201, 201, 192],
#         ...,
#         [201, 195, 186],
#         [200, 194, 183],
#         [199, 193, 182]],
#
#        [[203, 204, 194],
#         [203, 204, 194],
#         [203, 204, 195],
#         ...,
#         [202, 197, 187],
#         [202, 196, 185],
#         [201, 195, 184]],
#
#        ...,
#
#        [[168, 162, 148],
#         [174, 168, 154],
#         [176, 169, 157],
#         ...,
#         [181, 170, 166],
#         [180, 170, 167],
#         [179, 169, 165]],
#
#        [[166, 160, 145],
#         [174, 167, 152],
#         [175, 169, 155],
#         ...,
#         [179, 168, 164],
#         [180, 168, 167],
#         [180, 168, 166]],
#
#        [[165, 158, 143],
#         [174, 167, 152],
#         [175, 169, 155],
#         ...,
#         [175, 164, 161],
#         [175, 163, 162],
#         [174, 162, 160]]], dtype=uint8), array([[[133, 141, 158],
#         [127, 135, 152],
#         [163, 172, 189],
#         ...,
#         [166, 178, 183],
#         [130, 142, 147],
#         [128, 140, 146]],
#
#        [[131, 139, 156],
#         [130, 138, 155],
#         [162, 171, 188],
#         ...,
#         [163, 175, 181],
#         [128, 140, 146],
#         [126, 138, 144]],
#
#        [[166, 174, 191],
#         [165, 173, 190],
#         [176, 185, 202],
#         ...,
#         [176, 187, 194],
#         [167, 179, 186],
#         [168, 179, 187]],
#
#        ...,
#
#        [[171, 183, 195],
#         [166, 178, 190],
#         [179, 191, 203],
#         ...,
#         [169, 186, 199],
#         [155, 173, 186],
#         [154, 171, 185]],
#
#        [[141, 152, 166],
#         [135, 146, 160],
#         [176, 187, 201],
#         ...,
#         [147, 164, 178],
#         [127, 146, 161],
#         [127, 146, 161]],
#
#        [[139, 150, 164],
#         [139, 150, 164],
#         [174, 185, 199],
#         ...,
#         [147, 165, 178],
#         [126, 145, 160],
#         [126, 145, 160]]], dtype=uint8), array([[[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [251, 251, 251],
#         [253, 253, 253],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254],
#         ...,
#         [251, 251, 251],
#         [253, 253, 253],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [251, 251, 251],
#         [253, 253, 253],
#         [254, 254, 254]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]]], dtype=uint8), array([[[172, 170, 176],
#         [173, 172, 178],
#         [181, 179, 185],
#         ...,
#         [101, 101, 107],
#         [123, 123, 129],
#         [128, 128, 134]],
#
#        [[172, 170, 176],
#         [173, 171, 177],
#         [180, 178, 184],
#         ...,
#         [ 98,  98, 104],
#         [118, 118, 124],
#         [122, 122, 128]],
#
#        [[171, 168, 174],
#         [171, 169, 175],
#         [176, 174, 180],
#         ...,
#         [ 82,  82,  88],
#         [ 93,  93,  99],
#         [ 96,  96, 102]],
#
#        ...,
#
#        [[204, 197, 198],
#         [204, 198, 199],
#         [204, 198, 199],
#         ...,
#         [110, 104, 105],
#         [ 75,  69,  70],
#         [ 68,  62,  63]],
#
#        [[206, 200, 200],
#         [206, 200, 201],
#         [206, 200, 201],
#         ...,
#         [100,  95,  95],
#         [ 73,  67,  68],
#         [ 67,  61,  62]],
#
#        [[206, 200, 201],
#         [206, 200, 201],
#         [207, 201, 202],
#         ...,
#         [ 98,  92,  93],
#         [ 73,  67,  68],
#         [ 67,  61,  62]]], dtype=uint8), array([[[236, 217, 254],
#         [206, 191, 235],
#         [236, 227, 250],
#         ...,
#         [215, 208, 233],
#         [232, 225, 252],
#         [226, 219, 252]],
#
#        [[107,  93, 132],
#         [102,  88, 130],
#         [106,  98, 121],
#         ...,
#         [103,  96, 122],
#         [102,  97, 126],
#         [113, 106, 140]],
#
#        [[ 18,   8,  46],
#         [ 30,  18,  54],
#         [ 28,  21,  43],
#         ...,
#         [ 19,  12,  39],
#         [ 11,   6,  40],
#         [ 23,  16,  53]],
#
#        ...,
#
#        [[252, 253, 248],
#         [242, 243, 238],
#         [250, 250, 247],
#         ...,
#         [248, 250, 245],
#         [247, 247, 245],
#         [247, 247, 245]],
#
#        [[252, 253, 247],
#         [244, 246, 240],
#         [250, 251, 247],
#         ...,
#         [248, 250, 243],
#         [249, 250, 244],
#         [249, 250, 244]],
#
#        [[255, 255, 249],
#         [248, 250, 244],
#         [249, 250, 246],
#         ...,
#         [252, 253, 244],
#         [255, 255, 247],
#         [255, 255, 247]]], dtype=uint8), array([[[ 28,  67, 112],
#         [ 23,  62, 107],
#         [ 13,  52,  97],
#         ...,
#         [ 12,  62, 100],
#         [ 22,  65, 108],
#         [ 12,  54,  97]],
#
#        [[ 34,  73, 119],
#         [ 84, 123, 168],
#         [ 94, 133, 178],
#         ...,
#         [ 82, 133, 171],
#         [ 76, 121, 163],
#         [ 34,  77, 120]],
#
#        [[ 10,  49,  95],
#         [ 78, 117, 162],
#         [ 60,  98, 146],
#         ...,
#         [106, 158, 196],
#         [ 88, 135, 178],
#         [ 16,  61, 104]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8), array([[[249, 245, 251],
#         [254, 250, 254],
#         [240, 236, 241],
#         ...,
#         [130, 126, 133],
#         [101,  97, 103],
#         [100,  96, 102]],
#
#        [[253, 249, 254],
#         [253, 249, 255],
#         [240, 236, 242],
#         ...,
#         [129, 125, 132],
#         [102,  98, 104],
#         [102,  98, 104]],
#
#        [[246, 242, 247],
#         [244, 240, 246],
#         [236, 232, 238],
#         ...,
#         [145, 141, 148],
#         [100,  96, 102],
#         [ 98,  94, 100]],
#
#        ...,
#
#        [[244, 240, 246],
#         [246, 242, 248],
#         [231, 227, 233],
#         ...,
#         [173, 169, 175],
#         [199, 195, 200],
#         [197, 193, 200]],
#
#        [[252, 248, 254],
#         [251, 247, 253],
#         [218, 214, 221],
#         ...,
#         [178, 174, 180],
#         [213, 209, 215],
#         [214, 210, 216]],
#
#        [[250, 246, 252],
#         [252, 248, 254],
#         [217, 213, 219],
#         ...,
#         [179, 175, 181],
#         [215, 211, 217],
#         [215, 211, 217]]], dtype=uint8), array([[[199, 213, 207],
#         [197, 210, 209],
#         [206, 216, 225],
#         ...,
#         [172, 188, 201],
#         [178, 194, 200],
#         [178, 196, 197]],
#
#        [[192, 205, 202],
#         [204, 216, 218],
#         [211, 220, 232],
#         ...,
#         [175, 190, 204],
#         [178, 193, 201],
#         [178, 194, 199]],
#
#        [[193, 206, 209],
#         [206, 217, 226],
#         [205, 213, 231],
#         ...,
#         [173, 185, 203],
#         [178, 189, 203],
#         [179, 192, 203]],
#
#        ...,
#
#        [[174, 177, 202],
#         [181, 184, 211],
#         [189, 193, 221],
#         ...,
#         [196, 203, 221],
#         [200, 209, 223],
#         [202, 211, 223]],
#
#        [[173, 174, 200],
#         [179, 183, 208],
#         [189, 193, 220],
#         ...,
#         [196, 203, 220],
#         [197, 204, 218],
#         [200, 209, 219]],
#
#        [[159, 160, 186],
#         [166, 170, 195],
#         [179, 183, 210],
#         ...,
#         [202, 208, 226],
#         [200, 207, 221],
#         [203, 212, 222]]], dtype=uint8), array([[[ 24,  24,  24],
#         [ 20,  20,  20],
#         [ 14,  14,  14],
#         ...,
#         [  0,   0,   0],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[ 22,  22,  22],
#         [ 18,  18,  18],
#         [ 13,  13,  13],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  2,   2,   2]],
#
#        [[ 17,  17,  17],
#         [ 15,  15,  15],
#         [ 12,  12,  12],
#         ...,
#         [  3,   3,   3],
#         [  6,   6,   6],
#         [  9,   9,   9]],
#
#        ...,
#
#        [[252, 252, 252],
#         [249, 249, 249],
#         [247, 247, 247],
#         ...,
#         [253, 253, 253],
#         [250, 250, 250],
#         [249, 249, 249]],
#
#        [[249, 249, 249],
#         [249, 249, 249],
#         [247, 247, 247],
#         ...,
#         [252, 252, 252],
#         [250, 250, 250],
#         [247, 247, 247]],
#
#        [[250, 250, 250],
#         [249, 249, 249],
#         [245, 245, 245],
#         ...,
#         [252, 252, 252],
#         [247, 247, 247],
#         [249, 249, 249]]], dtype=uint8), array([[[ 63,  49, 204],
#         [ 60,  49, 197],
#         [ 54,  49, 186],
#         ...,
#         [ 79, 103, 206],
#         [122, 145, 243],
#         [142, 165, 255]],
#
#        [[ 57,  42, 202],
#         [ 57,  44, 198],
#         [ 57,  49, 193],
#         ...,
#         [ 75, 101, 201],
#         [120, 144, 241],
#         [139, 162, 255]],
#
#        [[ 53,  35, 203],
#         [ 54,  38, 201],
#         [ 58,  47, 202],
#         ...,
#         [ 68,  95, 191],
#         [117, 142, 237],
#         [135, 161, 254]],
#
#        ...,
#
#        [[ 89,  55, 231],
#         [ 85,  53, 229],
#         [ 81,  51, 227],
#         ...,
#         [ 68, 124, 172],
#         [ 60, 115, 164],
#         [ 57, 111, 160]],
#
#        [[ 77,  39, 221],
#         [ 72,  37, 218],
#         [ 73,  39, 220],
#         ...,
#         [ 36,  90, 142],
#         [ 44,  96, 149],
#         [ 48, 100, 153]],
#
#        [[ 67,  28, 214],
#         [ 69,  32, 216],
#         [ 70,  34, 218],
#         ...,
#         [ 23,  77, 130],
#         [ 37,  88, 144],
#         [ 43,  94, 150]]], dtype=uint8), array([[[199, 213, 207],
#         [197, 210, 209],
#         [206, 216, 225],
#         ...,
#         [172, 188, 201],
#         [178, 194, 200],
#         [178, 196, 197]],
#
#        [[192, 205, 202],
#         [204, 216, 218],
#         [211, 220, 232],
#         ...,
#         [175, 190, 204],
#         [178, 193, 201],
#         [178, 194, 199]],
#
#        [[193, 206, 209],
#         [206, 217, 226],
#         [205, 213, 231],
#         ...,
#         [173, 185, 203],
#         [178, 189, 203],
#         [179, 192, 203]],
#
#        ...,
#
#        [[174, 177, 202],
#         [181, 184, 211],
#         [189, 193, 221],
#         ...,
#         [196, 203, 221],
#         [200, 209, 223],
#         [202, 211, 223]],
#
#        [[173, 174, 200],
#         [179, 183, 208],
#         [189, 193, 220],
#         ...,
#         [196, 203, 220],
#         [197, 204, 218],
#         [200, 209, 219]],
#
#        [[159, 160, 186],
#         [166, 170, 195],
#         [179, 183, 210],
#         ...,
#         [202, 208, 226],
#         [200, 207, 221],
#         [203, 212, 222]]], dtype=uint8), array([[[ 33,  11,  69],
#         [ 53,  34,  84],
#         [154, 139, 179],
#         ...,
#         [ 37,  25,  61],
#         [ 32,  19,  58],
#         [ 29,  15,  56]],
#
#        [[ 35,  13,  71],
#         [ 48,  29,  80],
#         [115, 100, 140],
#         ...,
#         [ 37,  25,  61],
#         [ 47,  34,  72],
#         [100,  86, 125]],
#
#        [[ 39,  18,  74],
#         [ 46,  27,  77],
#         [ 77,  61, 101],
#         ...,
#         [ 46,  34,  70],
#         [ 77,  65, 102],
#         [163, 151, 188]],
#
#        ...,
#
#        [[ 41,  31,  65],
#         [ 36,  28,  60],
#         [ 54,  46,  74],
#         ...,
#         [ 60,  49,  81],
#         [112, 103, 132],
#         [197, 189, 215]],
#
#        [[ 43,  33,  69],
#         [ 38,  29,  62],
#         [ 29,  21,  51],
#         ...,
#         [ 80,  70, 101],
#         [156, 147, 174],
#         [223, 215, 240]],
#
#        [[ 36,  26,  62],
#         [ 33,  24,  58],
#         [ 18,  10,  41],
#         ...,
#         [104,  93, 125],
#         [193, 184, 210],
#         [217, 209, 232]]], dtype=uint8), array([[[ 28,  23,  54],
#         [ 42,  38,  70],
#         [ 51,  47,  81],
#         ...,
#         [119, 133, 151],
#         [ 97, 113, 137],
#         [ 96, 116, 141]],
#
#        [[  7,   4,  34],
#         [ 15,  12,  42],
#         [ 21,  19,  51],
#         ...,
#         [137, 151, 169],
#         [105, 123, 145],
#         [ 93, 113, 138]],
#
#        [[  2,   3,  27],
#         [  3,   3,  28],
#         [  4,   4,  31],
#         ...,
#         [149, 164, 180],
#         [115, 133, 153],
#         [ 92, 113, 136]],
#
#        ...,
#
#        [[  1,   2,  34],
#         [  8,  11,  42],
#         [ 67,  70, 100],
#         ...,
#         [ 17,  22,  41],
#         [ 18,  24,  44],
#         [ 27,  33,  54]],
#
#        [[  6,   8,  44],
#         [ 11,  15,  50],
#         [ 49,  51,  86],
#         ...,
#         [ 13,  18,  40],
#         [  9,  15,  38],
#         [  0,   3,  27]],
#
#        [[ 18,  21,  59],
#         [ 19,  22,  61],
#         [ 27,  30,  68],
#         ...,
#         [  9,  14,  36],
#         [  8,  12,  37],
#         [  0,   1,  26]]], dtype=uint8), array([[[ 28,  23,  54],
#         [ 42,  38,  70],
#         [ 51,  47,  81],
#         ...,
#         [119, 133, 151],
#         [ 97, 113, 137],
#         [ 96, 116, 141]],
#
#        [[  7,   4,  34],
#         [ 15,  12,  42],
#         [ 21,  19,  51],
#         ...,
#         [137, 151, 169],
#         [105, 123, 145],
#         [ 93, 113, 138]],
#
#        [[  2,   3,  27],
#         [  3,   3,  28],
#         [  4,   4,  31],
#         ...,
#         [149, 164, 180],
#         [115, 133, 153],
#         [ 92, 113, 136]],
#
#        ...,
#
#        [[  1,   2,  34],
#         [  8,  11,  42],
#         [ 67,  70, 100],
#         ...,
#         [ 17,  22,  41],
#         [ 18,  24,  44],
#         [ 27,  33,  54]],
#
#        [[  6,   8,  44],
#         [ 11,  15,  50],
#         [ 49,  51,  86],
#         ...,
#         [ 13,  18,  40],
#         [  9,  15,  38],
#         [  0,   3,  27]],
#
#        [[ 18,  21,  59],
#         [ 19,  22,  61],
#         [ 27,  30,  68],
#         ...,
#         [  9,  14,  36],
#         [  8,  12,  37],
#         [  0,   1,  26]]], dtype=uint8), array([[[138, 149, 160],
#         [141, 148, 157],
#         [145, 148, 152],
#         ...,
#         [  1,   6,  23],
#         [ 20,  38,  62],
#         [157, 188, 220]],
#
#        [[142, 151, 163],
#         [146, 151, 159],
#         [150, 151, 155],
#         ...,
#         [  1,   2,  19],
#         [ 26,  38,  63],
#         [149, 175, 206]],
#
#        [[141, 149, 158],
#         [145, 151, 157],
#         [144, 145, 149],
#         ...,
#         [  0,   1,  19],
#         [ 33,  43,  67],
#         [123, 146, 176]],
#
#        ...,
#
#        [[ 18,  20,  34],
#         [  9,  17,  31],
#         [ 92, 103, 117],
#         ...,
#         [  6,   7,   8],
#         [  2,   2,   6],
#         [ 95,  97, 105]],
#
#        [[ 15,  17,  31],
#         [  4,  12,  27],
#         [ 89, 100, 114],
#         ...,
#         [ 13,  13,  14],
#         [ 59,  58,  62],
#         [ 95,  97, 104]],
#
#        [[ 12,  15,  29],
#         [  8,  16,  31],
#         [ 75,  86,  99],
#         ...,
#         [111, 110, 113],
#         [116, 117, 121],
#         [121, 125, 130]]], dtype=uint8), array([[[187, 185, 227],
#         [185, 183, 225],
#         [186, 184, 226],
#         ...,
#         [187, 196, 211],
#         [199, 207, 224],
#         [199, 207, 224]],
#
#        [[186, 184, 226],
#         [185, 183, 225],
#         [186, 184, 226],
#         ...,
#         [186, 194, 211],
#         [196, 204, 221],
#         [196, 204, 221]],
#
#        [[180, 179, 221],
#         [180, 179, 221],
#         [180, 179, 221],
#         ...,
#         [168, 176, 194],
#         [180, 187, 205],
#         [180, 188, 206]],
#
#        ...,
#
#        [[190, 192, 225],
#         [188, 191, 224],
#         [175, 177, 210],
#         ...,
#         [186, 188, 217],
#         [193, 196, 224],
#         [195, 198, 226]],
#
#        [[200, 203, 234],
#         [198, 200, 231],
#         [185, 188, 219],
#         ...,
#         [196, 198, 228],
#         [204, 207, 235],
#         [206, 209, 237]],
#
#        [[200, 203, 234],
#         [197, 201, 231],
#         [186, 189, 220],
#         ...,
#         [196, 198, 228],
#         [204, 206, 236],
#         [204, 207, 235]]], dtype=uint8), array([[[ 48,  92, 129],
#         [ 61, 106, 143],
#         [ 54, 101, 137],
#         ...,
#         [ 47,  99, 138],
#         [ 51, 103, 140],
#         [ 42,  94, 131]],
#
#        [[ 55, 100, 137],
#         [ 81, 126, 163],
#         [ 87, 135, 171],
#         ...,
#         [ 81, 134, 171],
#         [ 74, 126, 163],
#         [ 53, 105, 142]],
#
#        [[ 50,  97, 132],
#         [ 84, 133, 167],
#         [ 93, 143, 178],
#         ...,
#         [ 86, 139, 176],
#         [ 77, 129, 166],
#         [ 48, 100, 136]],
#
#        ...,
#
#        [[ 38,  91, 128],
#         [ 79, 132, 169],
#         [ 89, 142, 179],
#         ...,
#         [ 91, 141, 177],
#         [ 85, 130, 166],
#         [ 55,  99, 135]],
#
#        [[ 46,  98, 134],
#         [ 71, 123, 160],
#         [ 77, 129, 165],
#         ...,
#         [ 84, 132, 168],
#         [ 78, 122, 158],
#         [ 57,  99, 134]],
#
#        [[ 44,  96, 133],
#         [ 54, 106, 143],
#         [ 51, 103, 139],
#         ...,
#         [ 55, 103, 139],
#         [ 61, 105, 139],
#         [ 55,  97, 132]]], dtype=uint8), array([[[141, 140, 149],
#         [141, 140, 149],
#         [142, 144, 150],
#         ...,
#         [141, 141, 150],
#         [143, 144, 154],
#         [136, 138, 148]],
#
#        [[141, 140, 149],
#         [140, 141, 149],
#         [142, 145, 150],
#         ...,
#         [145, 144, 154],
#         [143, 144, 154],
#         [140, 142, 152]],
#
#        [[137, 139, 145],
#         [138, 141, 147],
#         [140, 143, 148],
#         ...,
#         [145, 147, 154],
#         [141, 143, 152],
#         [140, 141, 150]],
#
#        ...,
#
#        [[171, 168, 173],
#         [162, 154, 160],
#         [113,  97, 102],
#         ...,
#         [ 91,  83,  93],
#         [110, 100, 112],
#         [133, 123, 135]],
#
#        [[168, 172, 177],
#         [172, 170, 175],
#         [132, 119, 124],
#         ...,
#         [119, 111, 122],
#         [ 76,  68,  79],
#         [ 87,  78,  91]],
#
#        [[164, 170, 175],
#         [174, 175, 179],
#         [162, 149, 155],
#         ...,
#         [175, 167, 178],
#         [153, 144, 157],
#         [109, 100, 113]]], dtype=uint8), array([[[245, 252, 255],
#         [245, 252, 255],
#         [245, 252, 255],
#         ...,
#         [114, 123, 102],
#         [103, 112,  91],
#         [107, 117,  94]],
#
#        [[245, 252, 255],
#         [245, 252, 255],
#         [245, 252, 255],
#         ...,
#         [142, 151, 131],
#         [153, 162, 141],
#         [164, 173, 152]],
#
#        [[245, 252, 255],
#         [245, 252, 255],
#         [245, 252, 255],
#         ...,
#         [149, 158, 140],
#         [160, 169, 150],
#         [173, 181, 163]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [250, 250, 250],
#         [252, 252, 252],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [246, 246, 246],
#         [247, 247, 247],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [253, 253, 253],
#         [255, 255, 255]]], dtype=uint8), array([[[ 39,  19,  72],
#         [ 31,  16,  65],
#         [150, 129, 176],
#         ...,
#         [ 38,  23,  67],
#         [ 34,  23,  57],
#         [ 26,  18,  42]],
#
#        [[ 39,  19,  70],
#         [ 40,  22,  73],
#         [115,  94, 145],
#         ...,
#         [ 35,  20,  64],
#         [ 29,  17,  51],
#         [108, 100, 123]],
#
#        [[ 38,  20,  68],
#         [ 47,  28,  79],
#         [ 72,  52, 105],
#         ...,
#         [ 32,  17,  60],
#         [ 43,  33,  65],
#         [200, 193, 213]],
#
#        ...,
#
#        [[ 42,  29,  66],
#         [ 39,  28,  62],
#         [ 51,  41,  72],
#         ...,
#         [ 29,  15,  55],
#         [136, 125, 160],
#         [236, 226, 244]],
#
#        [[ 42,  29,  68],
#         [ 39,  26,  64],
#         [ 31,  20,  54],
#         ...,
#         [ 64,  50,  89],
#         [188, 177, 210],
#         [225, 216, 237]],
#
#        [[ 44,  30,  72],
#         [ 37,  24,  64],
#         [ 16,   3,  39],
#         ...,
#         [101,  87, 127],
#         [216, 205, 237],
#         [203, 194, 221]]], dtype=uint8), array([[[229, 221, 191],
#         [232, 224, 194],
#         [218, 210, 181],
#         ...,
#         [178, 147, 138],
#         [234, 205, 193],
#         [237, 207, 196]],
#
#        [[232, 224, 194],
#         [230, 222, 192],
#         [223, 215, 185],
#         ...,
#         [174, 143, 133],
#         [234, 204, 193],
#         [236, 206, 195]],
#
#        [[172, 166, 135],
#         [170, 164, 133],
#         [177, 170, 139],
#         ...,
#         [157, 125, 115],
#         [164, 132, 121],
#         [164, 132, 121]],
#
#        ...,
#
#        [[129,  96,  77],
#         [130,  97,  78],
#         [113,  78,  61],
#         ...,
#         [198, 187, 175],
#         [233, 225, 213],
#         [234, 228, 215]],
#
#        [[215, 182, 163],
#         [213, 180, 161],
#         [178, 143, 126],
#         ...,
#         [247, 241, 228],
#         [255, 254, 241],
#         [255, 253, 240]],
#
#        [[218, 185, 166],
#         [215, 182, 163],
#         [175, 140, 123],
#         ...,
#         [247, 241, 228],
#         [255, 255, 242],
#         [255, 255, 242]]], dtype=uint8), array([[[ 27,  33,  48],
#         [ 46,  53,  80],
#         [ 52,  61,  76],
#         ...,
#         [ 58,  65,  85],
#         [ 55,  64,  82],
#         [ 58,  65,  85]],
#
#        [[ 29,  33,  47],
#         [ 51,  53,  68],
#         [ 61,  64,  85],
#         ...,
#         [ 48,  55,  72],
#         [ 49,  55,  75],
#         [ 54,  61,  75]],
#
#        [[ 52,  60,  83],
#         [ 43,  47,  65],
#         [ 55,  59,  83],
#         ...,
#         [206, 219, 235],
#         [204, 217, 233],
#         [199, 212, 226]],
#
#        ...,
#
#        [[ 72,  51,  50],
#         [ 72,  51,  50],
#         [ 72,  51,  50],
#         ...,
#         [ 72,  51,  50],
#         [ 72,  51,  50],
#         [ 72,  51,  50]],
#
#        [[ 72,  51,  50],
#         [ 72,  51,  50],
#         [ 72,  51,  50],
#         ...,
#         [ 72,  51,  50],
#         [ 72,  51,  50],
#         [ 72,  51,  50]],
#
#        [[ 72,  51,  50],
#         [ 72,  51,  50],
#         [ 72,  51,  50],
#         ...,
#         [ 72,  51,  50],
#         [ 72,  51,  50],
#         [ 72,  51,  50]]], dtype=uint8), array([[[ 34,  53, 163],
#         [ 33,  58, 162],
#         [ 29,  58, 165],
#         ...,
#         [ 30,  49, 160],
#         [ 32,  50, 166],
#         [ 33,  50, 161]],
#
#        [[ 30,  51, 160],
#         [ 30,  54, 163],
#         [ 41, 106, 199],
#         ...,
#         [ 32,  50, 163],
#         [ 31,  50, 159],
#         [ 35,  54, 165]],
#
#        [[ 34,  58, 169],
#         [ 29,  56, 164],
#         [125, 165, 195],
#         ...,
#         [ 34,  52, 166],
#         [ 32,  49, 159],
#         [ 28,  47, 158]],
#
#        ...,
#
#        [[ 30,  47, 150],
#         [ 30,  46, 152],
#         [ 29,  45, 152],
#         ...,
#         [ 31,  49, 156],
#         [ 26,  46, 153],
#         [ 30,  46, 153]],
#
#        [[ 32,  51, 154],
#         [ 33,  51, 159],
#         [ 30,  47, 157],
#         ...,
#         [ 29,  42, 147],
#         [ 28,  42, 147],
#         [ 25,  41, 142]],
#
#        [[ 33,  47, 155],
#         [ 32,  50, 157],
#         [ 29,  45, 156],
#         ...,
#         [ 28,  43, 145],
#         [ 29,  45, 146],
#         [ 27,  44, 142]]], dtype=uint8), array([[[ 36,  35, 166],
#         [ 48,  40, 169],
#         [ 40,  40, 164],
#         ...,
#         [ 32,  45, 153],
#         [142, 181, 240],
#         [130, 189, 243]],
#
#        [[ 39,  39, 170],
#         [ 40,  37, 165],
#         [ 40,  46, 162],
#         ...,
#         [ 35,  44, 161],
#         [ 80, 104, 203],
#         [ 43,  80, 163]],
#
#        [[ 36,  38, 168],
#         [ 41,  42, 169],
#         [ 29,  41, 149],
#         ...,
#         [ 37,  40, 165],
#         [ 34,  40, 162],
#         [ 32,  43, 154]],
#
#        ...,
#
#        [[ 26,  27,  91],
#         [ 28,  30,  95],
#         [ 27,  23,  95],
#         ...,
#         [ 24,  26,  89],
#         [ 26,  29,  92],
#         [ 19,  27,  90]],
#
#        [[ 29,  27,  90],
#         [ 25,  27,  92],
#         [ 23,  24,  91],
#         ...,
#         [ 15,  27,  88],
#         [ 32,  30,  93],
#         [ 22,  28,  90]],
#
#        [[ 35,  30,  91],
#         [ 30,  33,  97],
#         [ 23,  28,  90],
#         ...,
#         [ 16,  36,  94],
#         [ 34,  30,  92],
#         [ 24,  28,  89]]], dtype=uint8), array([[[213, 205, 198],
#         [213, 205, 198],
#         [221, 213, 206],
#         ...,
#         [ 57,  37,  42],
#         [ 68,  52,  59],
#         [ 68,  51,  54]],
#
#        [[211, 203, 195],
#         [217, 209, 202],
#         [216, 208, 200],
#         ...,
#         [ 66,  49,  50],
#         [ 57,  43,  47],
#         [ 83,  74,  76]],
#
#        [[212, 203, 199],
#         [218, 209, 206],
#         [221, 214, 206],
#         ...,
#         [ 57,  45,  49],
#         [ 99,  92, 102],
#         [171, 170, 177]],
#
#        ...,
#
#        [[ 45,  34,  31],
#         [ 50,  38,  36],
#         [ 46,  36,  33],
#         ...,
#         [ 33,  29,  28],
#         [ 31,  28,  24],
#         [ 27,  27,  27]],
#
#        [[ 48,  39,  36],
#         [ 52,  38,  39],
#         [ 52,  41,  38],
#         ...,
#         [ 35,  31,  30],
#         [ 30,  27,  23],
#         [ 32,  27,  27]],
#
#        [[ 52,  40,  36],
#         [ 44,  30,  32],
#         [ 44,  32,  32],
#         ...,
#         [ 29,  25,  24],
#         [ 25,  22,  18],
#         [ 27,  24,  20]]], dtype=uint8), array([[[155, 159, 160],
#         [156, 167, 165],
#         [160, 181, 178],
#         ...,
#         [ 95, 109,  61],
#         [115, 131,  89],
#         [138, 154, 113]],
#
#        [[135, 144, 146],
#         [142, 158, 156],
#         [157, 182, 178],
#         ...,
#         [ 81,  96,  51],
#         [ 97, 113,  75],
#         [115, 131,  93]],
#
#        [[114, 133, 135],
#         [126, 149, 149],
#         [148, 179, 176],
#         ...,
#         [102, 120,  80],
#         [114, 131,  97],
#         [125, 141, 108]],
#
#        ...,
#
#        [[138, 150, 145],
#         [150, 163, 157],
#         [152, 166, 158],
#         ...,
#         [115, 128, 114],
#         [ 95, 112,  96],
#         [ 86, 102,  87]],
#
#        [[127, 139, 132],
#         [146, 159, 150],
#         [147, 162, 148],
#         ...,
#         [104, 122, 104],
#         [ 74,  95,  75],
#         [ 60,  80,  61]],
#
#        [[122, 133, 125],
#         [142, 153, 143],
#         [141, 157, 140],
#         ...,
#         [ 96, 116,  97],
#         [ 66,  89,  67],
#         [ 52,  75,  53]]], dtype=uint8), array([[[ 10,  23,  73],
#         [ 32,  55, 111],
#         [ 30,  58, 116],
#         ...,
#         [101, 118, 170],
#         [ 67,  82, 130],
#         [ 96, 106, 150]],
#
#        [[  8,   1,   3],
#         [  0,   2,  14],
#         [  2,  11,  35],
#         ...,
#         [122, 148, 193],
#         [ 62,  86, 132],
#         [101, 123, 168]],
#
#        [[  2,   0,   3],
#         [  2,   1,   3],
#         [  4,   4,   8],
#         ...,
#         [128, 156, 198],
#         [101, 129, 174],
#         [ 68,  92, 138]],
#
#        ...,
#
#        [[  0,   0,  40],
#         [  5,  11,  51],
#         [ 38,  48,  82],
#         ...,
#         [ 11,  16,  53],
#         [  1,   3,  42],
#         [ 13,  29,  73]],
#
#        [[  0,   0,  43],
#         [  4,  13,  61],
#         [ 13,  24,  72],
#         ...,
#         [ 18,  21,  59],
#         [  0,   3,  39],
#         [  3,  11,  34]],
#
#        [[  4,  10,  57],
#         [  1,  10,  67],
#         [  0,  15,  80],
#         ...,
#         [ 19,  22,  60],
#         [ 22,  24,  63],
#         [  1,   1,  30]]], dtype=uint8), array([[[181, 175, 180],
#         [175, 171, 173],
#         [176, 172, 178],
#         ...,
#         [128, 150, 152],
#         [152, 174, 180],
#         [171, 180, 187]],
#
#        [[181, 174, 179],
#         [174, 170, 175],
#         [176, 172, 178],
#         ...,
#         [ 50,  45,  51],
#         [133, 145, 150],
#         [154, 174, 179]],
#
#        [[169, 161, 168],
#         [179, 174, 179],
#         [173, 168, 174],
#         ...,
#         [ 38,  21,  28],
#         [ 53,  48,  54],
#         [123, 134, 138]],
#
#        ...,
#
#        [[147, 109, 121],
#         [208, 191, 202],
#         [191, 198, 205],
#         ...,
#         [188, 180, 190],
#         [149, 141, 151],
#         [ 72,  62,  72]],
#
#        [[ 71,  42,  45],
#         [211, 182, 195],
#         [204, 194, 211],
#         ...,
#         [100,  91, 101],
#         [184, 176, 186],
#         [173, 164, 174]],
#
#        [[151, 134, 129],
#         [127,  93, 105],
#         [220, 195, 220],
#         ...,
#         [ 80,  69,  78],
#         [ 76,  66,  76],
#         [136, 127, 137]]], dtype=uint8), array([[[ 48,  37,  46],
#         [ 89,  78,  88],
#         [180, 169, 180],
#         ...,
#         [ 85,  82,  91],
#         [ 44,  41,  50],
#         [ 28,  25,  34]],
#
#        [[112, 101, 111],
#         [ 61,  50,  60],
#         [137, 126, 136],
#         ...,
#         [137, 134, 143],
#         [100,  96, 105],
#         [ 51,  48,  57]],
#
#        [[160, 149, 159],
#         [ 65,  53,  63],
#         [ 81,  70,  80],
#         ...,
#         [170, 167, 176],
#         [166, 163, 172],
#         [141, 138, 147]],
#
#        ...,
#
#        [[188, 180, 181],
#         [182, 174, 175],
#         [187, 179, 180],
#         ...,
#         [187, 179, 180],
#         [187, 179, 180],
#         [185, 177, 178]],
#
#        [[190, 182, 183],
#         [177, 169, 170],
#         [171, 164, 164],
#         ...,
#         [187, 179, 180],
#         [187, 179, 180],
#         [185, 177, 178]],
#
#        [[189, 181, 182],
#         [171, 163, 164],
#         [164, 156, 157],
#         ...,
#         [187, 179, 180],
#         [187, 179, 180],
#         [185, 177, 178]]], dtype=uint8), array([[[155, 159, 160],
#         [156, 167, 165],
#         [160, 181, 178],
#         ...,
#         [ 95, 109,  61],
#         [115, 131,  89],
#         [138, 154, 113]],
#
#        [[135, 144, 146],
#         [142, 158, 156],
#         [157, 182, 178],
#         ...,
#         [ 81,  96,  51],
#         [ 97, 113,  75],
#         [115, 131,  93]],
#
#        [[114, 133, 135],
#         [126, 149, 149],
#         [148, 179, 176],
#         ...,
#         [102, 120,  80],
#         [114, 131,  97],
#         [125, 141, 108]],
#
#        ...,
#
#        [[138, 150, 145],
#         [150, 163, 157],
#         [152, 166, 158],
#         ...,
#         [115, 128, 114],
#         [ 95, 112,  96],
#         [ 86, 102,  87]],
#
#        [[127, 139, 132],
#         [146, 159, 150],
#         [147, 162, 148],
#         ...,
#         [104, 122, 104],
#         [ 74,  95,  75],
#         [ 60,  80,  61]],
#
#        [[122, 133, 125],
#         [142, 153, 143],
#         [141, 157, 140],
#         ...,
#         [ 96, 116,  97],
#         [ 66,  89,  67],
#         [ 52,  75,  53]]], dtype=uint8), array([[[123, 123, 107],
#         [100, 100,  84],
#         [148, 148, 133],
#         ...,
#         [133, 132, 124],
#         [100,  98,  93],
#         [116, 115, 111]],
#
#        [[ 63,  63,  47],
#         [ 57,  57,  42],
#         [111, 110,  95],
#         ...,
#         [ 92,  90,  81],
#         [150, 149, 141],
#         [212, 213, 204]],
#
#        [[ 64,  64,  50],
#         [ 71,  71,  57],
#         [ 91,  91,  77],
#         ...,
#         [ 61,  61,  47],
#         [115, 115, 101],
#         [204, 204, 190]],
#
#        ...,
#
#        [[223, 224, 209],
#         [228, 229, 216],
#         [224, 225, 217],
#         ...,
#         [167, 162, 149],
#         [187, 181, 171],
#         [191, 184, 175]],
#
#        [[102, 106,  87],
#         [159, 162, 147],
#         [202, 202, 196],
#         ...,
#         [ 45,  43,  28],
#         [ 56,  52,  39],
#         [ 61,  55,  44]],
#
#        [[ 37,  41,  22],
#         [ 44,  47,  33],
#         [ 54,  54,  48],
#         ...,
#         [ 85,  82,  67],
#         [102,  97,  84],
#         [107, 101,  89]]], dtype=uint8), array([[[ 57,  40, 174],
#         [ 48,  36, 162],
#         [ 55,  55, 165],
#         ...,
#         [ 39,  56, 146],
#         [ 76,  95, 191],
#         [124, 143, 240]],
#
#        [[ 50,  36, 168],
#         [ 44,  35, 158],
#         [ 58,  61, 168],
#         ...,
#         [ 31,  48, 138],
#         [ 52,  69, 167],
#         [ 79,  97, 195]],
#
#        [[ 43,  36, 162],
#         [ 38,  36, 152],
#         [ 58,  65, 167],
#         ...,
#         [ 29,  45, 137],
#         [ 35,  51, 150],
#         [ 41,  57, 157]],
#
#        ...,
#
#        [[ 18,  41,  93],
#         [ 16,  39,  95],
#         [ 13,  32,  95],
#         ...,
#         [ 15,  29,  92],
#         [ 23,  29,  92],
#         [ 24,  29,  92]],
#
#        [[ 20,  42,  91],
#         [ 15,  38,  92],
#         [ 15,  35,  96],
#         ...,
#         [ 20,  36,  99],
#         [ 23,  29,  92],
#         [ 24,  29,  92]],
#
#        [[ 14,  37,  83],
#         [ 17,  39,  90],
#         [ 10,  30,  90],
#         ...,
#         [ 29,  47, 110],
#         [ 23,  29,  92],
#         [ 24,  29,  92]]], dtype=uint8), array([[[ 32, 161, 200],
#         [ 33, 167, 208],
#         [ 19, 164, 208],
#         ...,
#         [ 43,  58,  75],
#         [ 51,  65,  79],
#         [ 73,  87,  99]],
#
#        [[ 29, 153, 191],
#         [ 47, 177, 216],
#         [ 28, 167, 211],
#         ...,
#         [ 70,  84, 100],
#         [ 69,  82,  96],
#         [ 72,  86,  98]],
#
#        [[ 56, 169, 204],
#         [ 53, 172, 207],
#         [ 43, 172, 212],
#         ...,
#         [ 27,  39,  56],
#         [ 47,  59,  74],
#         [ 67,  78,  92]],
#
#        ...,
#
#        [[ 50,  78,  99],
#         [ 52,  94, 115],
#         [ 81, 147, 169],
#         ...,
#         [125, 167, 180],
#         [111, 162, 178],
#         [113, 170, 187]],
#
#        [[ 21,  53,  74],
#         [ 91, 138, 160],
#         [ 96, 169, 192],
#         ...,
#         [ 81, 124, 138],
#         [ 64, 116, 133],
#         [ 79, 137, 156]],
#
#        [[ 20,  54,  74],
#         [ 88, 138, 160],
#         [ 94, 169, 193],
#         ...,
#         [ 38,  81,  96],
#         [  5,  58,  77],
#         [  4,  63,  83]]], dtype=uint8), array([[[ 79,  62,  20],
#         [ 62,  42,   6],
#         [ 58,  34,   9],
#         ...,
#         [ 47,  57,  75],
#         [ 16,  28,  46],
#         [132, 147, 165]],
#
#        [[ 69,  49,  15],
#         [124, 104,  71],
#         [171, 152, 127],
#         ...,
#         [ 66,  78,  96],
#         [ 73,  87, 105],
#         [154, 168, 188]],
#
#        [[ 71,  49,  21],
#         [190, 168, 142],
#         [225, 209, 185],
#         ...,
#         [113, 126, 144],
#         [133, 147, 166],
#         [136, 150, 172]],
#
#        ...,
#
#        [[ 86,  98, 104],
#         [ 51,  62,  69],
#         [ 38,  48,  56],
#         ...,
#         [ 56,  86, 118],
#         [ 50,  80, 109],
#         [ 44,  74, 100]],
#
#        [[100, 112, 118],
#         [ 61,  70,  79],
#         [ 39,  48,  57],
#         ...,
#         [ 48,  76, 106],
#         [ 40,  69,  91],
#         [ 32,  62,  83]],
#
#        [[109, 121, 127],
#         [ 69,  78,  87],
#         [ 40,  50,  58],
#         ...,
#         [ 40,  68,  97],
#         [ 30,  59,  81],
#         [ 21,  51,  71]]], dtype=uint8), array([[[153, 153, 153],
#         [201, 201, 201],
#         [192, 192, 192],
#         ...,
#         [224, 224, 224],
#         [230, 230, 230],
#         [200, 200, 200]],
#
#        [[204, 204, 204],
#         [190, 190, 190],
#         [217, 217, 217],
#         ...,
#         [247, 247, 247],
#         [224, 224, 224],
#         [136, 136, 136]],
#
#        [[243, 243, 243],
#         [207, 207, 207],
#         [111, 111, 111],
#         ...,
#         [211, 211, 211],
#         [236, 236, 236],
#         [165, 165, 165]],
#
#        ...,
#
#        [[235, 235, 235],
#         [249, 249, 249],
#         [198, 198, 198],
#         ...,
#         [169, 169, 169],
#         [144, 144, 144],
#         [145, 145, 145]],
#
#        [[246, 246, 246],
#         [239, 239, 239],
#         [247, 247, 247],
#         ...,
#         [ 63,  63,  63],
#         [  7,   7,   7],
#         [ 34,  35,  34]],
#
#        [[213, 213, 213],
#         [205, 205, 205],
#         [232, 232, 232],
#         ...,
#         [ 53,  53,  53],
#         [  3,   3,   3],
#         [ 19,  20,  18]]], dtype=uint8), array([[[ 15, 129, 169],
#         [  7, 121, 161],
#         [  3, 115, 157],
#         ...,
#         [ 10, 101, 162],
#         [ 18, 111, 171],
#         [ 22, 117, 177]],
#
#        [[ 15, 127, 167],
#         [ 11, 123, 162],
#         [ 10, 120, 160],
#         ...,
#         [ 14, 105, 163],
#         [ 19, 112, 170],
#         [ 23, 116, 174]],
#
#        [[ 18, 127, 164],
#         [ 17, 125, 163],
#         [ 18, 125, 163],
#         ...,
#         [ 21, 110, 164],
#         [ 24, 114, 167],
#         [ 25, 115, 168]],
#
#        ...,
#
#        [[ 58, 113, 128],
#         [ 97, 153, 167],
#         [145, 202, 216],
#         ...,
#         [ 90, 164, 167],
#         [105, 181, 183],
#         [117, 195, 194]],
#
#        [[ 63, 120, 133],
#         [ 90, 148, 159],
#         [123, 182, 194],
#         ...,
#         [ 89, 164, 167],
#         [101, 178, 180],
#         [110, 190, 190]],
#
#        [[ 54, 113, 123],
#         [ 73, 132, 142],
#         [ 96, 157, 167],
#         ...,
#         [ 83, 159, 163],
#         [ 92, 171, 172],
#         [ 98, 178, 179]]], dtype=uint8), array([[[ 39,  52,  50],
#         [  8,  19,  17],
#         [ 16,  25,  22],
#         ...,
#         [227, 230, 235],
#         [ 65,  68,  73],
#         [ 17,  16,  20]],
#
#        [[136, 148, 146],
#         [ 27,  38,  36],
#         [  8,  15,  12],
#         ...,
#         [152, 155, 159],
#         [ 35,  37,  41],
#         [ 14,  12,  17]],
#
#        [[201, 211, 209],
#         [ 45,  56,  52],
#         [  5,  12,   8],
#         ...,
#         [138, 141, 144],
#         [ 10,  12,  15],
#         [  8,   7,  10]],
#
#        ...,
#
#        [[183, 186, 184],
#         [ 46,  49,  47],
#         [  5,   6,   4],
#         ...,
#         [106, 102,  99],
#         [ 41,  37,  34],
#         [ 23,  21,  21]],
#
#        [[196, 199, 198],
#         [ 34,  37,  36],
#         [ 12,  14,  12],
#         ...,
#         [145, 142, 138],
#         [ 26,  23,  19],
#         [ 19,  17,  17]],
#
#        [[157, 162, 161],
#         [ 11,  16,  14],
#         [ 23,  26,  24],
#         ...,
#         [250, 247, 242],
#         [ 21,  18,  13],
#         [  2,   0,   0]]], dtype=uint8), array([[[100, 104, 200],
#         [ 29,  47, 179],
#         [ 72,  79, 193],
#         ...,
#         [ 81,  68, 192],
#         [ 33,  32, 194],
#         [186, 189, 230]],
#
#        [[134, 137, 214],
#         [  6,   1, 235],
#         [ 13,  13, 252],
#         ...,
#         [ 16,   2, 243],
#         [  3,   2, 233],
#         [214, 223, 252]],
#
#        [[176, 171, 252],
#         [  1,   7, 234],
#         [  1,  17, 244],
#         ...,
#         [  8,  12, 247],
#         [  1,   7, 226],
#         [220, 214, 255]],
#
#        ...,
#
#        [[133, 142, 242],
#         [  9,   8, 237],
#         [  1,   6, 248],
#         ...,
#         [  7,   8, 250],
#         [  5,   6, 246],
#         [223, 219, 254]],
#
#        [[ 94, 101, 202],
#         [ 36,  17, 252],
#         [ 20,  13, 220],
#         ...,
#         [ 22,  13, 205],
#         [ 22,  14, 239],
#         [203, 200, 251]],
#
#        [[222, 229, 253],
#         [225, 241, 254],
#         [217, 213, 255],
#         ...,
#         [230, 226, 254],
#         [215, 235, 254],
#         [243, 240, 255]]], dtype=uint8), array([[[110,  88, 136],
#         [110,  88, 136],
#         [110,  88, 136],
#         ...,
#         [229, 245, 251],
#         [229, 245, 251],
#         [229, 245, 251]],
#
#        [[110,  88, 136],
#         [110,  88, 136],
#         [110,  88, 136],
#         ...,
#         [229, 245, 251],
#         [229, 245, 251],
#         [229, 245, 251]],
#
#        [[110,  88, 136],
#         [110,  88, 136],
#         [110,  88, 136],
#         ...,
#         [229, 245, 251],
#         [229, 245, 251],
#         [229, 245, 251]],
#
#        ...,
#
#        [[229, 245, 251],
#         [229, 245, 251],
#         [229, 245, 251],
#         ...,
#         [ 76,  33,  78],
#         [ 76,  33,  78],
#         [ 76,  33,  78]],
#
#        [[229, 245, 251],
#         [229, 245, 251],
#         [229, 245, 251],
#         ...,
#         [ 76,  33,  78],
#         [ 76,  33,  78],
#         [ 76,  33,  78]],
#
#        [[229, 245, 251],
#         [229, 245, 251],
#         [229, 245, 251],
#         ...,
#         [ 76,  33,  78],
#         [ 76,  33,  78],
#         [ 76,  33,  78]]], dtype=uint8), array([[[243, 247, 251],
#         [193, 196, 204],
#         [ 22,  31,  46],
#         ...,
#         [246, 250, 253],
#         [243, 255, 255],
#         [161, 167, 165]],
#
#        [[242, 248, 254],
#         [201, 206, 213],
#         [ 18,  27,  38],
#         ...,
#         [239, 247, 253],
#         [218, 231, 235],
#         [150, 157, 157]],
#
#        [[ 81,  93, 101],
#         [ 66,  75,  82],
#         [ 71,  79,  86],
#         ...,
#         [ 55,  67,  81],
#         [ 39,  52,  60],
#         [ 42,  50,  54]],
#
#        ...,
#
#        [[ 83,  94, 104],
#         [ 56,  65,  74],
#         [ 76,  85,  89],
#         ...,
#         [ 52,  64,  77],
#         [ 25,  36,  44],
#         [ 36,  44,  53]],
#
#        [[244, 252, 253],
#         [198, 207, 209],
#         [ 15,  27,  32],
#         ...,
#         [237, 246, 252],
#         [214, 225, 229],
#         [144, 153, 160]],
#
#        [[240, 245, 241],
#         [181, 189, 188],
#         [ 28,  41,  46],
#         ...,
#         [243, 252, 255],
#         [225, 237, 240],
#         [149, 158, 163]]], dtype=uint8), array([[[218, 225, 222],
#         [217, 224, 220],
#         [216, 223, 218],
#         ...,
#         [ 28,  37,  24],
#         [ 11,  20,   9],
#         [  0,   9,   0]],
#
#        [[218, 225, 222],
# ...
#         [101, 116, 118],
#         [112, 127, 129]],
#
#        [[156, 168, 170],
#         [146, 157, 160],
#         [152, 163, 166],
#         ...,
#         [ 36,  50,  54],
#         [ 33,  46,  49],
#         [ 40,  52,  55]],
#
#        ...,
#
#        [[148, 159, 161],
#         [151, 162, 164],
#         [153, 163, 167],
#         ...,
#         [141, 152, 159],
#         [141, 153, 158],
#         [155, 168, 170]],
#
#        [[140, 149, 152],
#         [152, 161, 164],
#         [147, 156, 159],
#         ...,
#         [142, 153, 160],
#         [140, 152, 156],
#         [156, 167, 170]],
#
#        [[130, 139, 142],
#         [150, 159, 162],
#         [138, 147, 151],
#         ...,
#         [150, 162, 167],
#         [151, 162, 166],
#         [156, 165, 168]]], dtype=uint8), array([[[ 67,  68,  64],
#         [ 68,  69,  65],
#         [ 70,  69,  65],
#         ...,
#         [ 23,  31,  29],
#         [ 26,  23,  21],
#         [ 39,  29,  29]],
#
#        [[ 58,  57,  53],
#         [ 59,  57,  53],
#         [ 60,  57,  54],
#         ...,
#         [ 23,  31,  29],
#         [ 27,  23,  23],
#         [ 35,  27,  26]],
#
#        [[ 51,  46,  42],
#         [ 51,  46,  42],
#         [ 52,  46,  43],
#         ...,
#         [ 25,  33,  31],
#         [ 28,  25,  26],
#         [ 30,  23,  23]],
#
#        ...,
#
#        [[ 28,  27,  17],
#         [ 28,  27,  17],
#         [ 29,  27,  17],
#         ...,
#         [ 37,  46,  56],
#         [ 93, 100, 114],
#         [ 64,  71,  86]],
#
#        [[ 27,  27,  17],
#         [ 27,  27,  17],
#         [ 28,  27,  17],
#         ...,
#         [ 19,  25,  35],
#         [ 57,  63,  77],
#         [ 57,  64,  79]],
#
#        [[ 26,  27,  17],
#         [ 26,  27,  17],
#         [ 28,  27,  17],
#         ...,
#         [  2,   5,  15],
#         [ 23,  29,  43],
#         [ 49,  56,  71]]], dtype=uint8), array([[[ 93, 100, 120],
#         [210, 217, 230],
#         [244, 246, 255],
#         ...,
#         [100, 123, 153],
#         [154, 171, 195],
#         [ 94, 107, 121]],
#
#        [[212, 218, 230],
#         [232, 238, 250],
#         [238, 240, 251],
#         ...,
#         [142, 161, 190],
#         [116, 129, 151],
#         [ 86,  95, 108]],
#
#        [[237, 241, 254],
#         [242, 245, 255],
#         [247, 248, 253],
#         ...,
#         [106, 117, 145],
#         [111, 116, 135],
#         [200, 204, 210]],
#
#        ...,
#
#        [[130, 150, 167],
#         [123, 141, 156],
#         [ 60,  68,  80],
#         ...,
#         [ 56, 119, 152],
#         [ 56, 116, 153],
#         [ 63, 117, 161]],
#
#        [[171, 184, 199],
#         [ 49,  61,  75],
#         [100, 109, 118],
#         ...,
#         [ 66, 124, 159],
#         [ 65, 120, 156],
#         [ 86, 133, 171]],
#
#        [[ 67,  73,  84],
#         [102, 107, 117],
#         [207, 211, 215],
#         ...,
#         [ 64, 115, 155],
#         [ 85, 132, 168],
#         [163, 199, 229]]], dtype=uint8), array([[[ 21,  32,  84],
#         [ 23,  34,  86],
#         [ 25,  36,  86],
#         ...,
#         [ 95, 127, 166],
#         [ 96, 129, 170],
#         [ 39,  74, 114]],
#
#        [[ 20,  31,  83],
#         [ 22,  33,  84],
#         [ 24,  35,  85],
#         ...,
#         [105, 137, 176],
#         [104, 136, 177],
#         [ 43,  78, 118]],
#
#        [[ 19,  29,  80],
#         [ 21,  31,  81],
#         [ 23,  33,  83],
#         ...,
#         [136, 167, 205],
#         [122, 155, 195],
#         [ 55,  89, 129]],
#
#        ...,
#
#        [[132, 157, 174],
#         [102, 125, 143],
#         [  5,  24,  42],
#         ...,
#         [156, 196, 211],
#         [153, 193, 208],
#         [153, 193, 208]],
#
#        [[131, 157, 174],
#         [ 97, 121, 139],
#         [  2,  20,  38],
#         ...,
#         [157, 195, 210],
#         [154, 193, 208],
#         [154, 193, 208]],
#
#        [[130, 156, 173],
#         [ 93, 117, 135],
#         [  0,  17,  35],
#         ...,
#         [156, 195, 210],
#         [154, 193, 208],
#         [154, 193, 208]]], dtype=uint8), array([[[ 76,  61,  69],
#         [ 55,  41,  49],
#         [ 29,  16,  27],
#         ...,
#         [ 18,  11,  27],
#         [ 33,  22,  38],
#         [ 57,  47,  63]],
#
#        [[161, 145, 153],
#         [150, 137, 145],
#         [126, 114, 124],
#         ...,
#         [ 94,  86, 102],
#         [134, 124, 140],
#         [154, 144, 160]],
#
#        [[213, 198, 206],
#         [201, 188, 196],
#         [187, 175, 185],
#         ...,
#         [153, 145, 160],
#         [188, 179, 194],
#         [206, 195, 209]],
#
#        ...,
#
#        [[232, 211, 215],
#         [233, 213, 218],
#         [232, 211, 218],
#         ...,
#         [231, 214, 221],
#         [233, 215, 222],
#         [229, 211, 218]],
#
#        [[230, 210, 214],
#         [233, 213, 218],
#         [232, 212, 219],
#         ...,
#         [230, 213, 220],
#         [231, 213, 220],
#         [231, 213, 220]],
#
#        [[232, 212, 217],
#         [233, 213, 218],
#         [231, 211, 219],
#         ...,
#         [229, 212, 219],
#         [228, 210, 217],
#         [234, 216, 223]]], dtype=uint8), array([[[  9,  21,  69],
#         [ 10,  20,  67],
#         [ 17,  25,  69],
#         ...,
#         [ 18,  22,  67],
#         [ 16,  20,  68],
#         [ 21,  26,  75]],
#
#        [[  9,  21,  69],
#         [ 16,  26,  73],
#         [ 16,  24,  69],
#         ...,
#         [ 21,  25,  70],
#         [ 19,  25,  71],
#         [ 18,  23,  69]],
#
#        [[  9,  22,  68],
#         [ 13,  24,  71],
#         [ 19,  26,  73],
#         ...,
#         [ 23,  29,  71],
#         [ 22,  30,  72],
#         [ 20,  30,  70]],
#
#        ...,
#
#        [[  1,  13,  29],
#         [  5,  13,  28],
#         [ 11,  11,  24],
#         ...,
#         [137, 141, 138],
#         [140, 140, 140],
#         [133, 131, 133]],
#
#        [[  0,  13,  32],
#         [  4,  14,  31],
#         [ 11,  11,  27],
#         ...,
#         [136, 142, 138],
#         [142, 143, 143],
#         [135, 135, 135]],
#
#        [[  0,  11,  30],
#         [  2,  13,  31],
#         [ 11,  12,  28],
#         ...,
#         [132, 138, 134],
#         [137, 139, 138],
#         [138, 138, 138]]], dtype=uint8), array([[[150, 146, 142],
#         [154, 148, 153],
#         [160, 151, 148],
#         ...,
#         [ 43,  62,  51],
#         [ 44,  57,  54],
#         [ 33,  37,  37]],
#
#        [[151, 148, 143],
#         [157, 152, 140],
#         [157, 152, 146],
#         ...,
#         [ 34,  46,  40],
#         [ 50,  69,  65],
#         [ 45,  65,  63]],
#
#        [[151, 145, 148],
#         [150, 141, 145],
#         [153, 145, 145],
#         ...,
#         [ 31,  39,  28],
#         [ 46,  61,  54],
#         [ 43,  67,  61]],
#
#        ...,
#
#        [[ 59,  66,  50],
#         [ 28,  37,  24],
#         [ 39,  45,  40],
#         ...,
#         [133, 144, 131],
#         [136, 145, 131],
#         [139, 140, 128]],
#
#        [[ 50,  48,  33],
#         [ 29,  25,  27],
#         [ 28,  38,  41],
#         ...,
#         [134, 143, 134],
#         [134, 143, 132],
#         [134, 141, 133]],
#
#        [[ 70,  66,  62],
#         [ 53,  49,  58],
#         [ 57,  68,  66],
#         ...,
#         [138, 146, 134],
#         [137, 143, 134],
#         [139, 141, 137]]], dtype=uint8), array([[[246, 253, 255],
#         [246, 253, 255],
#         [249, 254, 255],
#         ...,
#         [254, 254, 254],
#         [255, 254, 254],
#         [255, 255, 255]],
#
#        [[249, 254, 255],
#         [248, 252, 254],
#         [248, 251, 252],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 253, 252],
#         [252, 252, 252],
#         [253, 252, 252],
#         ...,
#         [254, 255, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[254, 255, 255],
#         [254, 255, 255],
#         [255, 254, 255],
#         ...,
#         [254, 254, 253],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[253, 255, 255],
#         [253, 255, 255],
#         [254, 255, 255],
#         ...,
#         [254, 254, 254],
#         [255, 253, 255],
#         [255, 253, 255]],
#
#        [[253, 255, 255],
#         [253, 255, 255],
#         [254, 255, 255],
#         ...,
#         [254, 254, 254],
#         [255, 253, 255],
#         [255, 251, 255]]], dtype=uint8), array([[[112,  91,  94],
#         [188, 167, 170],
#         [226, 205, 207],
#         ...,
#         [ 67,  25,  22],
#         [ 89,  43,  41],
#         [135,  90,  87]],
#
#        [[200, 179, 182],
#         [192, 170, 173],
#         [172, 151, 153],
#         ...,
#         [ 97,  58,  54],
#         [127,  84,  82],
#         [165, 122, 119]],
#
#        [[237, 215, 220],
#         [223, 202, 205],
#         [198, 178, 180],
#         ...,
#         [118,  81,  79],
#         [135,  96,  95],
#         [148, 108, 106]],
#
#        ...,
#
#        [[115, 140, 127],
#         [115, 139, 127],
#         [117, 139, 129],
#         ...,
#         [138, 122, 123],
#         [150, 134, 135],
#         [146, 129, 130]],
#
#        [[116, 140, 128],
#         [116, 140, 128],
#         [117, 139, 129],
#         ...,
#         [101,  83,  84],
#         [118, 100, 101],
#         [121, 103, 104]],
#
#        [[116, 140, 128],
#         [116, 140, 128],
#         [117, 138, 129],
#         ...,
#         [ 84,  66,  67],
#         [ 52,  34,  35],
#         [ 42,  24,  25]]], dtype=uint8), array([[[225, 244, 249],
#         [225, 244, 249],
#         [225, 244, 249],
#         ...,
#         [ 51,  46,  48],
#         [108, 103, 105],
#         [207, 204, 206]],
#
#        [[225, 244, 249],
#         [225, 244, 249],
#         [225, 244, 249],
#         ...,
#         [ 75,  69,  71],
#         [149, 145, 147],
#         [232, 229, 231]],
#
#        [[225, 244, 249],
#         [225, 244, 249],
#         [225, 244, 249],
#         ...,
#         [ 83,  76,  79],
#         [167, 161, 164],
#         [236, 231, 234]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [248, 248, 248],
#         [249, 249, 249],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [250, 250, 250],
#         [253, 253, 253]]], dtype=uint8), array([[[ 76,  61,  69],
#         [ 55,  41,  49],
#         [ 29,  16,  27],
#         ...,
#         [ 18,  11,  27],
#         [ 33,  22,  38],
#         [ 57,  47,  63]],
#
#        [[161, 145, 153],
#         [150, 137, 145],
#         [126, 114, 124],
#         ...,
#         [ 94,  86, 102],
#         [134, 124, 140],
#         [154, 144, 160]],
#
#        [[213, 198, 206],
#         [201, 188, 196],
#         [187, 175, 185],
#         ...,
#         [153, 145, 160],
#         [188, 179, 194],
#         [206, 195, 209]],
#
#        ...,
#
#        [[232, 211, 215],
#         [233, 213, 218],
#         [232, 211, 218],
#         ...,
#         [231, 214, 221],
#         [233, 215, 222],
#         [229, 211, 218]],
#
#        [[230, 210, 214],
#         [233, 213, 218],
#         [232, 212, 219],
#         ...,
#         [230, 213, 220],
#         [231, 213, 220],
#         [231, 213, 220]],
#
#        [[232, 212, 217],
#         [233, 213, 218],
#         [231, 211, 219],
#         ...,
#         [229, 212, 219],
#         [228, 210, 217],
#         [234, 216, 223]]], dtype=uint8), array([[[ 20,  62, 109],
#         [ 42,  87, 134],
#         [ 33,  78, 125],
#         ...,
#         [209, 211, 186],
#         [212, 210, 180],
#         [212, 210, 179]],
#
#        [[ 27,  70, 117],
#         [ 46,  92, 139],
#         [ 30,  75, 122],
#         ...,
#         [205, 208, 184],
#         [212, 211, 182],
#         [212, 210, 180]],
#
#        [[ 42,  88, 135],
#         [ 47,  93, 140],
#         [ 21,  66, 113],
#         ...,
#         [189, 197, 177],
#         [201, 206, 181],
#         [199, 204, 178]],
#
#        ...,
#
#        [[122,  98,  82],
#         [110,  99,  97],
#         [ 63,  79,  96],
#         ...,
#         [ 67,  31,  21],
#         [ 80,  39,  26],
#         [ 72,  30,  17]],
#
#        [[133, 105,  87],
#         [116,  97,  87],
#         [ 67,  73,  79],
#         ...,
#         [ 64,  31,  22],
#         [ 73,  32,  19],
#         [ 70,  29,  16]],
#
#        [[131, 101,  81],
#         [114,  90,  76],
#         [ 83,  79,  78],
#         ...,
#         [ 59,  28,  18],
#         [ 76,  35,  23],
#         [ 79,  37,  24]]], dtype=uint8), array([[[174, 160, 178],
#         [ 86,  72,  90],
#         [ 72,  56,  73],
#         ...,
#         [222, 217, 230],
#         [234, 232, 242],
#         [237, 234, 243]],
#
#        [[104,  91, 107],
#         [ 59,  46,  62],
#         [130, 115, 129],
#         ...,
#         [138, 132, 146],
#         [237, 234, 244],
#         [226, 223, 232]],
#
#        [[ 59,  49,  61],
#         [ 60,  51,  62],
#         [163, 152, 162],
#         ...,
#         [ 57,  51,  66],
#         [159, 155, 166],
#         [237, 231, 242]],
#
#        ...,
#
#        [[104, 106, 107],
#         [ 75,  76,  80],
#         [150, 150, 156],
#         ...,
#         [ 48,  38,  61],
#         [ 50,  41,  62],
#         [ 45,  38,  52]],
#
#        [[ 56,  57,  60],
#         [ 56,  56,  61],
#         [ 55,  55,  63],
#         ...,
#         [ 60,  49,  73],
#         [ 54,  46,  65],
#         [ 83,  76,  88]],
#
#        [[ 48,  49,  53],
#         [ 61,  61,  67],
#         [ 32,  31,  40],
#         ...,
#         [206, 196, 218],
#         [ 86,  77,  96],
#         [138, 131, 144]]], dtype=uint8), array([[[209, 207, 210],
#         [180, 186, 193],
#         [182, 194, 202],
#         ...,
#         [230, 239, 245],
#         [149, 161, 171],
#         [ 83,  98, 110]],
#
#        [[154, 158, 161],
#         [187, 193, 200],
#         [154, 161, 169],
#         ...,
#         [245, 251, 254],
#         [239, 248, 251],
#         [223, 234, 240]],
#
#        [[125, 134, 137],
#         [192, 198, 203],
#         [152, 155, 163],
#         ...,
#         [249, 252, 253],
#         [246, 248, 252],
#         [243, 245, 248]],
#
#        ...,
#
#        [[247, 246, 247],
#         [185, 189, 194],
#         [120, 124, 132],
#         ...,
#         [244, 248, 253],
#         [118, 125, 130],
#         [ 99, 107, 114]],
#
#        [[240, 244, 245],
#         [ 47,  51,  57],
#         [ 30,  33,  42],
#         ...,
#         [235, 244, 246],
#         [220, 232, 235],
#         [206, 221, 224]],
#
#        [[148, 155, 159],
#         [  0,   0,   8],
#         [  0,   1,   9],
#         ...,
#         [247, 251, 253],
#         [246, 249, 253],
#         [245, 248, 252]]], dtype=uint8), array([[[ 71,  57,  82],
#         [ 93,  91, 108],
#         [ 62,  71,  98],
#         ...,
#         [ 74,  92, 188],
#         [ 48,  66, 148],
#         [ 61,  76, 113]],
#
#        [[ 80,  67,  92],
#         [ 82,  82, 100],
#         [ 58,  68,  96],
#         ...,
#         [ 75,  93, 189],
#         [ 57,  75, 157],
#         [ 54,  70, 108]],
#
#        [[ 97,  86, 113],
#         [ 61,  65,  84],
#         [ 51,  63,  94],
#         ...,
#         [ 77,  96, 191],
#         [ 74,  94, 175],
#         [ 42,  59,  97]],
#
#        ...,
#
#        [[217, 233, 254],
#         [209, 235, 253],
#         [206, 237, 254],
#         ...,
#         [200, 239, 253],
#         [206, 241, 250],
#         [211, 238, 252]],
#
#        [[216, 232, 253],
#         [209, 235, 252],
#         [206, 237, 254],
#         ...,
#         [201, 239, 253],
#         [206, 241, 251],
#         [211, 238, 252]],
#
#        [[216, 231, 253],
#         [210, 234, 252],
#         [207, 237, 254],
#         ...,
#         [202, 239, 252],
#         [206, 241, 250],
#         [211, 238, 252]]], dtype=uint8), array([[[180, 177, 179],
#         [184, 181, 177],
#         [184, 185, 178],
#         ...,
#         [148, 155, 148],
#         [160, 168, 153],
#         [155, 165, 148]],
#
#        [[181, 182, 176],
#         [179, 179, 174],
#         [182, 178, 176],
#         ...,
#         [150, 157, 161],
#         [145, 153, 153],
#         [139, 148, 144]],
#
#        [[178, 176, 174],
#         [175, 175, 170],
#         [182, 178, 174],
#         ...,
#         [150, 157, 161],
#         [150, 156, 155],
#         [147, 155, 145]],
#
#        ...,
#
#        [[ 14,  13,  13],
#         [ 11,  15,   3],
#         [ 15,  17,  11],
#         ...,
#         [ 97, 103, 109],
#         [ 98, 112,  95],
#         [100, 117,  93]],
#
#        [[ 20,  14,  24],
#         [ 17,  15,  14],
#         [ 14,  13,  11],
#         ...,
#         [100, 108, 109],
#         [102, 109, 106],
#         [103, 107, 109]],
#
#        [[  1,  18,  10],
#         [ 27,  55,  40],
#         [ 68,  80,  77],
#         ...,
#         [ 62,  73,  83],
#         [ 97, 104, 100],
#         [104, 105,  95]]], dtype=uint8)]

# %%
X = np.array(X)
X = X/255
y = np.array(y)

# %%
X
# Out:
# array([[[[0.54117647, 0.54117647, 0.56470588],
#          [0.55294118, 0.55294118, 0.57647059],
#          [0.54901961, 0.54509804, 0.56862745],
#          ...,
#          [0.57254902, 0.55686275, 0.59215686],
#          [0.56862745, 0.56470588, 0.6       ],
#          [0.54901961, 0.54117647, 0.57647059]],
#
#         [[0.54901961, 0.56470588, 0.58431373],
#          [0.54509804, 0.56470588, 0.58431373],
#          [0.54117647, 0.55686275, 0.57647059],
#          ...,
#          [0.56078431, 0.57254902, 0.59215686],
#          [0.54509804, 0.56470588, 0.58431373],
#          [0.54117647, 0.55686275, 0.57647059]],
#
#         [[0.51764706, 0.54117647, 0.56078431],
#          [0.5372549 , 0.56078431, 0.58039216],
#          [0.53333333, 0.55686275, 0.57647059],
#          ...,
#          [0.55686275, 0.57647059, 0.59607843],
#          [0.54901961, 0.57254902, 0.59215686],
#          [0.5372549 , 0.56078431, 0.58039216]],
#
#         ...,
#
#         [[0.68235294, 0.65882353, 0.68235294],
#          [0.61960784, 0.63921569, 0.65882353],
#          [0.39607843, 0.43137255, 0.40392157],
#          ...,
#          [0.1372549 , 0.06666667, 0.10588235],
#          [0.42745098, 0.36078431, 0.38823529],
#          [0.68627451, 0.63137255, 0.65882353]],
#
#         [[0.67843137, 0.65490196, 0.68235294],
#          [0.66666667, 0.6745098 , 0.70588235],
#          [0.56862745, 0.64705882, 0.65490196],
#          ...,
#          [0.56078431, 0.58823529, 0.59215686],
#          [0.12156863, 0.09411765, 0.10196078],
#          [0.21960784, 0.11764706, 0.16862745]],
#
#         [[0.71372549, 0.65490196, 0.68627451],
#          [0.69803922, 0.66666667, 0.70980392],
#          [0.61568627, 0.69019608, 0.6745098 ],
#          ...,
#          [0.6745098 , 0.66666667, 0.69411765],
#          [0.63529412, 0.65098039, 0.6745098 ],
#          [0.48627451, 0.47843137, 0.50196078]]],
#
#
#        [[[0.43529412, 0.34901961, 0.5372549 ],
#          [0.41568627, 0.3372549 , 0.52156863],
#          [0.43137255, 0.35294118, 0.52941176],
#          ...,
#          [0.91372549, 0.98431373, 0.98823529],
#          [0.90196078, 0.97647059, 0.97647059],
#          [0.91372549, 0.98431373, 0.98039216]],
#
#         [[0.43137255, 0.34509804, 0.53333333],
#          [0.42352941, 0.34509804, 0.52941176],
#          [0.42745098, 0.34901961, 0.52941176],
#          ...,
#          [0.91764706, 0.97254902, 0.99215686],
#          [0.92941176, 0.98039216, 0.99215686],
#          [0.94509804, 0.99607843, 0.99607843]],
#
#         [[0.42745098, 0.34509804, 0.52941176],
#          [0.42745098, 0.34901961, 0.53333333],
#          [0.43137255, 0.34117647, 0.5372549 ],
#          ...,
#          [0.84705882, 0.88235294, 0.91764706],
#          [0.78823529, 0.81176471, 0.85490196],
#          [0.78823529, 0.80392157, 0.84705882]],
#
#         ...,
#
#         [[0.89803922, 0.97254902, 0.98431373],
#          [0.90588235, 0.96862745, 0.99607843],
#          [0.8627451 , 0.89411765, 0.94509804],
#          ...,
#          [0.29019608, 0.12941176, 0.30588235],
#          [0.29411765, 0.13333333, 0.30196078],
#          [0.29411765, 0.13333333, 0.29803922]],
#
#         [[0.91372549, 0.98823529, 0.99607843],
#          [0.91764706, 0.96862745, 1.        ],
#          [0.80784314, 0.82352941, 0.89019608],
#          ...,
#          [0.29411765, 0.1254902 , 0.30980392],
#          [0.29803922, 0.12941176, 0.30588235],
#          [0.29803922, 0.12941176, 0.29803922]],
#
#         [[0.88627451, 0.96078431, 0.98823529],
#          [0.92941176, 0.98039216, 0.99607843],
#          [0.81960784, 0.82745098, 0.89019608],
#          ...,
#          [0.29411765, 0.1254902 , 0.30980392],
#          [0.30588235, 0.1254902 , 0.30588235],
#          [0.30588235, 0.12941176, 0.29803922]]],
#
#
#        [[[0.78431373, 0.92156863, 0.63529412],
#          [0.34901961, 0.55686275, 0.20784314],
#          [0.22745098, 0.51764706, 0.07843137],
#          ...,
#          [0.70980392, 0.90980392, 0.62352941],
#          [0.30196078, 0.47843137, 0.23137255],
#          [0.65882353, 0.81568627, 0.56862745]],
#
#         [[0.45882353, 0.62352941, 0.29411765],
#          [0.74117647, 0.96078431, 0.58431373],
#          [0.23137255, 0.52156863, 0.07843137],
#          ...,
#          [0.55686275, 0.76862745, 0.43921569],
#          [0.21568627, 0.41176471, 0.11372549],
#          [0.67058824, 0.83921569, 0.55686275]],
#
#         [[0.3254902 , 0.5372549 , 0.12941176],
#          [0.62745098, 0.8745098 , 0.45098039],
#          [0.56078431, 0.83921569, 0.39607843],
#          ...,
#          [0.32941176, 0.57254902, 0.16078431],
#          [0.23137255, 0.45882353, 0.06666667],
#          [0.69019608, 0.86666667, 0.53333333]],
#
#         ...,
#
#         [[0.7372549 , 0.85490196, 0.56078431],
#          [0.23921569, 0.44313725, 0.05490196],
#          [0.29803922, 0.57647059, 0.09019608],
#          ...,
#          [0.56078431, 0.80392157, 0.41960784],
#          [0.5254902 , 0.70980392, 0.41176471],
#          [0.69019608, 0.81176471, 0.58431373]],
#
#         [[0.47058824, 0.61960784, 0.29411765],
#          [0.31372549, 0.5254902 , 0.1254902 ],
#          [0.23921569, 0.51764706, 0.03137255],
#          ...,
#          [0.35686275, 0.6       , 0.20784314],
#          [0.74901961, 0.92156863, 0.65098039],
#          [0.77254902, 0.87843137, 0.69803922]],
#
#         [[0.26666667, 0.50588235, 0.0745098 ],
#          [0.28235294, 0.54901961, 0.10588235],
#          [0.24705882, 0.55686275, 0.0627451 ],
#          ...,
#          [0.27058824, 0.50980392, 0.10196078],
#          [0.61960784, 0.76470588, 0.52941176],
#          [0.9254902 , 0.99607843, 0.87843137]]],
#
#
#        ...,
#
#
#        [[[0.81960784, 0.81176471, 0.82352941],
#          [0.70588235, 0.72941176, 0.75686275],
#          [0.71372549, 0.76078431, 0.79215686],
#          ...,
#          [0.90196078, 0.9372549 , 0.96078431],
#          [0.58431373, 0.63137255, 0.67058824],
#          [0.3254902 , 0.38431373, 0.43137255]],
#
#         [[0.60392157, 0.61960784, 0.63137255],
#          [0.73333333, 0.75686275, 0.78431373],
#          [0.60392157, 0.63137255, 0.6627451 ],
#          ...,
#          [0.96078431, 0.98431373, 0.99607843],
#          [0.9372549 , 0.97254902, 0.98431373],
#          [0.8745098 , 0.91764706, 0.94117647]],
#
#         [[0.49019608, 0.5254902 , 0.5372549 ],
#          [0.75294118, 0.77647059, 0.79607843],
#          [0.59607843, 0.60784314, 0.63921569],
#          ...,
#          [0.97647059, 0.98823529, 0.99215686],
#          [0.96470588, 0.97254902, 0.98823529],
#          [0.95294118, 0.96078431, 0.97254902]],
#
#         ...,
#
#         [[0.96862745, 0.96470588, 0.96862745],
#          [0.7254902 , 0.74117647, 0.76078431],
#          [0.47058824, 0.48627451, 0.51764706],
#          ...,
#          [0.95686275, 0.97254902, 0.99215686],
#          [0.4627451 , 0.49019608, 0.50980392],
#          [0.38823529, 0.41960784, 0.44705882]],
#
#         [[0.94117647, 0.95686275, 0.96078431],
#          [0.18431373, 0.2       , 0.22352941],
#          [0.11764706, 0.12941176, 0.16470588],
#          ...,
#          [0.92156863, 0.95686275, 0.96470588],
#          [0.8627451 , 0.90980392, 0.92156863],
#          [0.80784314, 0.86666667, 0.87843137]],
#
#         [[0.58039216, 0.60784314, 0.62352941],
#          [0.        , 0.        , 0.03137255],
#          [0.        , 0.00392157, 0.03529412],
#          ...,
#          [0.96862745, 0.98431373, 0.99215686],
#          [0.96470588, 0.97647059, 0.99215686],
#          [0.96078431, 0.97254902, 0.98823529]]],
#
#
#        [[[0.27843137, 0.22352941, 0.32156863],
#          [0.36470588, 0.35686275, 0.42352941],
#          [0.24313725, 0.27843137, 0.38431373],
#          ...,
#          [0.29019608, 0.36078431, 0.7372549 ],
#          [0.18823529, 0.25882353, 0.58039216],
#          [0.23921569, 0.29803922, 0.44313725]],
#
#         [[0.31372549, 0.2627451 , 0.36078431],
#          [0.32156863, 0.32156863, 0.39215686],
#          [0.22745098, 0.26666667, 0.37647059],
#          ...,
#          [0.29411765, 0.36470588, 0.74117647],
#          [0.22352941, 0.29411765, 0.61568627],
#          [0.21176471, 0.2745098 , 0.42352941]],
#
#         [[0.38039216, 0.3372549 , 0.44313725],
#          [0.23921569, 0.25490196, 0.32941176],
#          [0.2       , 0.24705882, 0.36862745],
#          ...,
#          [0.30196078, 0.37647059, 0.74901961],
#          [0.29019608, 0.36862745, 0.68627451],
#          [0.16470588, 0.23137255, 0.38039216]],
#
#         ...,
#
#         [[0.85098039, 0.91372549, 0.99607843],
#          [0.81960784, 0.92156863, 0.99215686],
#          [0.80784314, 0.92941176, 0.99607843],
#          ...,
#          [0.78431373, 0.9372549 , 0.99215686],
#          [0.80784314, 0.94509804, 0.98039216],
#          [0.82745098, 0.93333333, 0.98823529]],
#
#         [[0.84705882, 0.90980392, 0.99215686],
#          [0.81960784, 0.92156863, 0.98823529],
#          [0.80784314, 0.92941176, 0.99607843],
#          ...,
#          [0.78823529, 0.9372549 , 0.99215686],
#          [0.80784314, 0.94509804, 0.98431373],
#          [0.82745098, 0.93333333, 0.98823529]],
#
#         [[0.84705882, 0.90588235, 0.99215686],
#          [0.82352941, 0.91764706, 0.98823529],
#          [0.81176471, 0.92941176, 0.99607843],
#          ...,
#          [0.79215686, 0.9372549 , 0.98823529],
#          [0.80784314, 0.94509804, 0.98039216],
#          [0.82745098, 0.93333333, 0.98823529]]],
#
#
#        [[[0.70588235, 0.69411765, 0.70196078],
#          [0.72156863, 0.70980392, 0.69411765],
#          [0.72156863, 0.7254902 , 0.69803922],
#          ...,
#          [0.58039216, 0.60784314, 0.58039216],
#          [0.62745098, 0.65882353, 0.6       ],
#          [0.60784314, 0.64705882, 0.58039216]],
#
#         [[0.70980392, 0.71372549, 0.69019608],
#          [0.70196078, 0.70196078, 0.68235294],
#          [0.71372549, 0.69803922, 0.69019608],
#          ...,
#          [0.58823529, 0.61568627, 0.63137255],
#          [0.56862745, 0.6       , 0.6       ],
#          [0.54509804, 0.58039216, 0.56470588]],
#
#         [[0.69803922, 0.69019608, 0.68235294],
#          [0.68627451, 0.68627451, 0.66666667],
#          [0.71372549, 0.69803922, 0.68235294],
#          ...,
#          [0.58823529, 0.61568627, 0.63137255],
#          [0.58823529, 0.61176471, 0.60784314],
#          [0.57647059, 0.60784314, 0.56862745]],
#
#         ...,
#
#         [[0.05490196, 0.05098039, 0.05098039],
#          [0.04313725, 0.05882353, 0.01176471],
#          [0.05882353, 0.06666667, 0.04313725],
#          ...,
#          [0.38039216, 0.40392157, 0.42745098],
#          [0.38431373, 0.43921569, 0.37254902],
#          [0.39215686, 0.45882353, 0.36470588]],
#
#         [[0.07843137, 0.05490196, 0.09411765],
#          [0.06666667, 0.05882353, 0.05490196],
#          [0.05490196, 0.05098039, 0.04313725],
#          ...,
#          [0.39215686, 0.42352941, 0.42745098],
#          [0.4       , 0.42745098, 0.41568627],
#          [0.40392157, 0.41960784, 0.42745098]],
#
#         [[0.00392157, 0.07058824, 0.03921569],
#          [0.10588235, 0.21568627, 0.15686275],
#          [0.26666667, 0.31372549, 0.30196078],
#          ...,
#          [0.24313725, 0.28627451, 0.3254902 ],
#          [0.38039216, 0.40784314, 0.39215686],
#          [0.40784314, 0.41176471, 0.37254902]]]])

# %%
from sklearn.model_selection import train_test_split
#Spliting into test val train
X_train, X_test_val, Y_train, y_test_val = train_test_split(X, y, test_size=0.2, random_state=0)
X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val)

# %%
X_train, X_test,Y_train, Y_test = train_test_split(X, y, test_size=0.2)

# %%
# Define Ukuran Batch size , dan luas lebar citra

batch_size = 32
img_height = 256
img_width = 256

# %%
import tensorflow.keras.layers as tfl
import tensorflow as tf
path = 'Dataset'

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=1234,
    image_size=(img_height, img_width),
    batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=1234,
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 300 files belonging to 3 classes.
# Using 240 files for training.
# Found 300 files belonging to 3 classes.
# Using 60 files for validation.

# %%
# Cek 3 Kelas dataset
class_names = train_ds.class_names
print(class_names)
# Out:
# ['bribil', 'picis', 'sen']

# %%
# Cek ukuran gambar stelah di re scale 1./255 : : : : : : :

for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  break
# Out:
# (32, 256, 256, 3)

# %% [markdown]
# 32 berarti Batch size nya 256 ,256 merupakan nilai Height dan Width nya
# 3 adalah jumlah kanal nya

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
# from keras.utils.np_utils import to_categorical
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, AvgPool2D, BatchNormalization, Reshape, Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
import matplotlib.pyplot as plt

# %%
annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x, verbose=0)
styles=[':','-.','--','-',':','-.','--','-',':','-.','--','-']

# %%
num_classes = len(class_names)
nets = 3    
model = [0] * nets

for j in range(3):
    model[j]= Sequential()
    model[j].add(layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)))
    model[j].add(Conv2D(16, kernel_size=5, padding='same', activation='relu'))
    model[j].add(MaxPool2D())
    if j > 0:
        model[j].add(Conv2D(32, kernel_size=5, padding='same', activation='relu'))
        model[j].add(MaxPool2D())
    if j > 1:
        model[j].add(Conv2D(64, kernel_size=5, padding='same', activation='relu'))
        model[j].add(MaxPool2D(padding='same'))
    if j > 2:
        model[j].add(Conv2D(128, kernel_size=5,
                     padding='same', activation='relu'))
        model[j].add(MaxPool2D(padding='same'))
   # if j > 3:
    #    model[j].add(Conv2D(256, kernel_size=5,
     #                padding='same', activation='relu'))
      #  model[j].add(MaxPool2D(padding='same'))
    

    #layers.Conv2D(32, 3, padding='same', activation='relu'),
    #layers.AveragePooling2D(),
    #layers.Conv2D(64, 3, padding='same', activation='relu'),
    #layers.AveragePooling2D(),
    model[j].add(Flatten())
    model[j].add(Dense(512, activation='relu'))
    #model[j].add(Dense(10, activation='softmax'))
    model[j].add(Dense(num_classes))
    model[j].compile(optimizer='adam',
                          loss=tf.keras.losses.SparseCategoricalCrossentropy(
                              from_logits=True),
                          metrics=['accuracy'])

# %%
# CREATE VALIDATION SET
X_train2, X_val2, Y_train2, Y_val2 = train_test_split(X_train, Y_train, test_size = 0.2)
# TRAIN NETWORKS
history = [0] * nets
names = ["(Conv+Max)x1", "(Conv+Max)x2", "(Conv+Max)x3"]
epochs = 20
for j in range(nets):
    history[j] = model[j].fit(X_train2,Y_train2, batch_size=32, epochs = epochs, 
        validation_data = (X_val2,Y_val2), callbacks=[annealer], verbose=0)
    print("CNN {0}: Epochs={1:d}, Train accuracy={2:.5f}, Validation accuracy={3:.5f}".format(
        names[j],epochs,max(history[j].history['accuracy']),max(history[j].history['val_accuracy']) ))
# Out:
# CNN (Conv+Max)x1: Epochs=20, Train accuracy=0.94271, Validation accuracy=0.64583
# CNN (Conv+Max)x2: Epochs=20, Train accuracy=0.34375, Validation accuracy=0.33333
# CNN (Conv+Max)x3: Epochs=20, Train accuracy=0.34896, Validation accuracy=0.33333

# %%
# PLOT ACCURACIES
plt.figure(figsize=(15, 5))
for i in range(nets):
    plt.plot(history[i].history['val_accuracy'], linestyle=styles[i])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(names, loc='upper left')
axes = plt.gca()
axes.set_ylim([0, 1])
plt.show()

# %% [markdown]
# Bisa kita lihat dr grafik diatas. Kita dapat simpulkan jika ketiganya memiliki akurasi diatas 85 % . Namun, yang terbaik yaitu (C-P)x2 karena memiliki akurasi tertinggi dan untuk alasan efisiensi kita pilih yang x2.
#
# Oleh karena itu , kita memilih 2 Subsampling untuk arsitektur kita sebagai jumlah subsampling yg paling efisien untuk klasifikasi rempah rimpang

# %%
num_classes = len(class_names)
nets = 6
model = [0] * nets

for j in range(6):
    model[j] = Sequential()
    model[j].add(layers.Rescaling(
        1./255, input_shape=(img_height, img_width, 3)))
    model[j].add(Conv2D(j*8+8, kernel_size=5, padding='same', activation='relu'))
    model[j].add(MaxPool2D())
   # model[j].add(Conv2D(j*16+16, kernel_size=5, padding='same', activation='relu'))
   # model[j].add(MaxPool2D())
    #model[j].add(Conv2D(j*32+32, kernel_size=5, padding='same', activation='relu'))
    #model[j].add(MaxPool2D(padding='same'))

    model[j].add(Flatten())
    model[j].add(Dense(128, activation='relu'))
    model[j].add(Dense(num_classes))
    model[j].compile(optimizer='adam',
                     loss=tf.keras.losses.SparseCategoricalCrossentropy(
                         from_logits=True),
                     metrics=['accuracy'])

# %%
# CREATE VALIDATION SET
X_train2, X_val2, Y_train2, Y_val2 = train_test_split(X_train, Y_train, test_size = 0.2)
# TRAIN NETWORKS
history = [0] * nets
names = ["8 maps", "16 maps", "24 maps", "32 maps", "40 maps", "48 maps"]
epochs = 20
for j in range(nets):
    history[j] = model[j].fit(X_train2,Y_train2, batch_size=32, epochs = epochs, 
        validation_data = (X_val2,Y_val2), callbacks=[annealer], verbose=0)
    print("CNN {0}: Epochs={1:d}, Train accuracy={2:.5f}, Validation accuracy={3:.5f}".format(
        names[j],epochs,max(history[j].history['accuracy']),max(history[j].history['val_accuracy']) ))
# Out:
# CNN 8 maps: Epochs=20, Train accuracy=0.85417, Validation accuracy=0.62500
# CNN 16 maps: Epochs=20, Train accuracy=0.36458, Validation accuracy=0.41667
# CNN 24 maps: Epochs=20, Train accuracy=0.34375, Validation accuracy=0.33333
# CNN 32 maps: Epochs=20, Train accuracy=0.85938, Validation accuracy=0.66667
# CNN 40 maps: Epochs=20, Train accuracy=0.81771, Validation accuracy=0.62500
# CNN 48 maps: Epochs=20, Train accuracy=0.78125, Validation accuracy=0.52083

# %%
# PLOT ACCURACIES
plt.figure(figsize=(15, 5))
for i in range(nets):
    plt.plot(history[i].history['val_accuracy'], linestyle=styles[i])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(names, loc='upper left')
axes = plt.gca()
axes.set_ylim([0, 1])
plt.show()

# %% [markdown]
# dilihat dari grafik diatas, maka dpt disimpulkan bahwa 64 feature map lah yang tertinggi namun pada epoch 17,5 bernilai sama dengan feature map 32. oleh karena itu, untuk alasan efisiensi, yang digunakan dalam arsitektur cnn kita adalah 32 feature map.  karena fm32 mendapat nilai yang cukup tinggi senilai 0.8825 pada epoch 20 hampir sama dengan fm48 yang bernilai sama dan fm64 yang memiliki selisih 0.03.

# %%
num_classes = len(class_names)
nets = 8
model = [0] * nets

for j in range(8):
    model[j] = Sequential()
    model[j].add(layers.Rescaling(
        1./255, input_shape=(img_height, img_width, 3)))
    model[j].add(Conv2D(32, kernel_size=5, padding='same', activation='relu'))
    model[j].add(MaxPool2D())
    model[j].add(Dropout(j*0.1))
    #model[j].add(Conv2D(64, kernel_size=5, padding='same', activation='relu'))
   # model[j].add(MaxPool2D())
   # model[j].add(Dropout(j*0.1))
    #model[j].add(Conv2D(j*32+32, kernel_size=5, padding='same', activation='relu'))
    #model[j].add(MaxPool2D(padding='same'))

    model[j].add(Flatten())
    model[j].add(Dense(128, activation='relu'))
    model[j].add(Dropout(j*0.1))
    model[j].add(Dense(num_classes))
    model[j].compile(optimizer='adam',
                     loss=tf.keras.losses.SparseCategoricalCrossentropy(
                         from_logits=True),
                     metrics=['accuracy'])

# %%
# CREATE VALIDATION SET
X_train2, X_val2, Y_train2, Y_val2 = train_test_split(X_train, Y_train, test_size = 0.2)
# TRAIN NETWORKS
history = [0] * nets
names = ["D=0","D=0.1","D=0.2","D=0.3","D=0.4","D=0.5","D=0.6","D=0.7"]
epochs = 20
for j in range(nets):
    history[j] = model[j].fit(X_train2,Y_train2, batch_size=32, epochs = epochs, 
        validation_data = (X_val2,Y_val2), callbacks=[annealer], verbose=0)
    print("CNN {0}: Epochs={1:d}, Train accuracy={2:.5f}, Validation accuracy={3:.5f}".format(
        names[j],epochs,max(history[j].history['accuracy']),max(history[j].history['val_accuracy']) ))
# Out:
# CNN D=0: Epochs=20, Train accuracy=0.82292, Validation accuracy=0.56250
# CNN D=0.1: Epochs=20, Train accuracy=0.36458, Validation accuracy=0.25000
# CNN D=0.2: Epochs=20, Train accuracy=0.82292, Validation accuracy=0.60417
# CNN D=0.3: Epochs=20, Train accuracy=0.57812, Validation accuracy=0.45833
# CNN D=0.4: Epochs=20, Train accuracy=0.70833, Validation accuracy=0.47917
# CNN D=0.5: Epochs=20, Train accuracy=0.55208, Validation accuracy=0.33333
# CNN D=0.6: Epochs=20, Train accuracy=0.36458, Validation accuracy=0.45833
# CNN D=0.7: Epochs=20, Train accuracy=0.40625, Validation accuracy=0.25000

# %%
# PLOT ACCURACIES   
plt.figure(figsize=(15, 5))
for i in range(nets):
    plt.plot(history[i].history['val_accuracy'], linestyle=styles[i])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(names, loc='upper left')
axes = plt.gca()
axes.set_ylim([0, 1])
plt.show()

# %% [markdown]
# Summary from thats graphs is Dropout with x0% was the most eficients because from epoch 1 to 15 had significant higher eficients from others rate . althougt from dropout 20% lacking a bit when epoch above 20. but overall Dropout with 30% was the winner of this experiment.

# %% [markdown]
# Kesimpulan akhir
#
# Training CNN memiliki keragaman parameter dan nilai biasnya pada masing-masing layer sehingga bisa diartikan jika CNN merupakan proses yang acak. Acak dari segi nilai hyperparameter ataupun nilai keluaran setiap arsitekturnya selalu berbeda. Inilah yang membuat eksperimen seperti ini susah untuk dilakukan karena setiap kita meng run arsitektur kita dengan parameter yang sama seperti sebelumnya, hasilnya bisa saja beda setiap waktunya. Olehkarena itu, kita harus selalu mencoba puluhan bahkan sampai ratusan eksperimen untuk menarik sebuah rata-rata dari setiap training model.  ketiga eksperimen pun sudah saya run 1 bulanan dengan nilai epoch , batch size, subsampling, optimizers, dan feature map yang berbeda beda dengan layer arsitektur yang berbeda beda pula sehingga bisa saya simpulkan penelitian ini sudah menarik nilai rata-rata dari setiap modelnya. Untuk arsitektur yang paling optimal sendiri sesuai dengan apa yang ketiga eksperimen saya sudah lakukan sebelumnya untuk mengklasifikasi rempah rimpang dengan menggunakan convolutional neural network adalah dengan kombinasi 2 subsampling dengan dua layer konvolusi dengan feature map bernilai 32 dan 64 di kedua subsampling dan nilai dropout sebesar 30%. Dengan begitu jika kita rakit ulang menjadi sbuah arsitektur CNN, maka model tersebut akan mendapat nilai akurasi sebesar 97%.
